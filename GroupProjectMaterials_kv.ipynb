# %% [markdown]
# ## Installing packages

# %% [markdown]
# I would make a new environment, open JupyterLab, then open a terminal to install the necessary packages. <br>
# You need to run: <br>
# pip install mp-api <br>
# pip install matminer <br>
# pip install pymatgen==2023.12.18 <br>
# mp-api will automatically install pymatgen, but the most recent version is not compatible with matminer so you need to downgrade it to an older version (like 18/12/2023),

# %% [markdown]
# ## Importing basic packages and Material Project API

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from mp_api.client import MPRester

# %% [markdown]
# ## Filling dataframe with perovskite data

# %%
with MPRester("EclqWMXn0DY3CAOSELD3xvCjEVhlcEYp") as mpr:
    perovskites = mpr.materials.summary.search(formula=["ABC3"], fields = ["material_id", "structure", "band_gap", "theoretical", "is_stable"])
# mpr.materials.summary works similar to mpr.summary
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/4555 [00:00<?, ?it/s]

# %%
with MPRester("EclqWMXn0DY3CAOSELD3xvCjEVhlcEYp") as mpr:
    perovskites = mpr.summary.search(formula=["ABC3"], fields = ["material_id", "structure", "band_gap", "theoretical", "is_stable"])
# Out:
# C:\Users\Kshitij Vashisth\AppData\Local\Temp\ipykernel_20684\1141923278.py:2: DeprecationWarning: Accessing summary data through MPRester.summary is deprecated. Please use MPRester.materials.summary instead.
#   perovskites = mpr.summary.search(formula=["ABC3"], fields = ["material_id", "structure", "band_gap", "theoretical", "is_stable"])
# Retrieving SummaryDoc documents:   0%|          | 0/4555 [00:00<?, ?it/s]

# %%
ids = []
for i in range(4555):
    single = perovskites[i]
    ids.append(single.material_id)

# %%
structures = []
for i in range(4555):
    single = perovskites[i]
    structures.append(single.structure)

# %%
band_gaps = []
for i in range(4555):
    single = perovskites[i]
    band_gaps.append(single.band_gap)

# %%
theory = []
for i in range(4555):
    single = perovskites[i]
    theory.append(single.theoretical)

# %%
stable = []
for i in range(4555):
    single = perovskites[i]
    stable.append(single.is_stable)

# %%
perov_df = pd.DataFrame(
    {"material ids": ids,
     "structure": structures,
     "band gaps": band_gaps,
     "theoretical": theory,
     "stable": stable
    })

# %%
perov_df
# Out:
#      material ids                                          structure  \
# 0      mp-1183115  [[0. 0. 0.] Ac, [1.92931693 1.92931693 1.92931...
# 1      mp-1183052  [[0. 0. 0.] Ac, [1.860834 1.860834 1.860834] B...
# 2       mp-866101  [[0. 0. 0.] Ac, [1.97214345 1.97215113 1.97213...
# 3       mp-864606  [[0. 0. 0.] Ac, [1.9566578 1.9566578 1.9566578...
# 4       mp-861502  [[0. 0. 0.] Ac, [1.97678086 1.9767782  1.97678...
# ...           ...                                                ...
# 4550     mp-20325  [[2.11778054 2.11778054 0.        ] Ti, [2.117...
# 4551     mp-21233  [[0.         2.09394211 2.09394211] Ti, [2.093...
# 4552    mp-760414  [[1.14486018e+00 3.98291320e+00 1.08399671e-04...
# 4553    mp-644483  [[2.08307401 0.         2.08249963] Ti, [0.   ...
# 4554      mp-4563  [[0.         2.12210771 2.12210003] Ti, [2.122...
#
#       band gaps  theoretical  stable
# 0        4.1024         True    True
# 1        0.8071         True   False
# 2        2.0031         True    True
# 3        0.0000         True    True
# 4        0.9888         True    True
# ...         ...          ...     ...
# 4550     0.0000        False    True
# 4551     0.0000        False   False
# 4552     0.0000         True   False
# 4553     0.0000        False    True
# 4554     0.0000        False   False
#
# [4555 rows x 5 columns]

# %%
perov_df
# Out:
#      material ids                                          structure  \
# 0      mp-1183115  [[0. 0. 0.] Ac, [1.92931693 1.92931693 1.92931...
# 1      mp-1183052  [[0. 0. 0.] Ac, [1.860834 1.860834 1.860834] B...
# 2       mp-866101  [[0. 0. 0.] Ac, [1.97214345 1.97215113 1.97213...
# 3       mp-864606  [[0. 0. 0.] Ac, [1.9566578 1.9566578 1.9566578...
# 4       mp-861502  [[0. 0. 0.] Ac, [1.97678086 1.9767782  1.97678...
# ...           ...                                                ...
# 4550     mp-20852  [[2.78317726 2.5080982  1.93598463] Nd, [5.375...
# 4551   mp-1079171  [[ 2.06204844 -3.65368509  2.08529374] Nd, [2....
# 4552     mp-22106  [[0.04398497 5.1712759  5.70338325] Nd, [2.647...
# 4553    mp-571167  [[ 2.76233118  8.83858657 13.75898303] Nd, [ 6...
# 4554   mp-1186312  [[2.247597 2.247597 2.247597] Nd, [0. 0. 0.] N...
#
#       band gaps  theoretical  stable
# 0        4.1024         True    True
# 1        0.8071         True   False
# 2        2.0031         True    True
# 3        0.0000         True    True
# 4        0.9888         True    True
# ...         ...          ...     ...
# 4550     1.8980        False    True
# 4551     0.0000        False    True
# 4552     0.0000        False    True
# 4553     0.0000        False    True
# 4554     0.0000         True   False
#
# [4555 rows x 5 columns]

# %%
perov_df.to_csv('perov_df.csv', index=False)

# %% [markdown]
# ## Manipulating data - removing theoretical materials, converting "stable" into 1s and 0s

# %%
real_perovs = perov_df[perov_df["theoretical"]==False]

# %%
real_perovs
# Out:
#      material ids                                          structure  \
# 14     mp-1105645  [[7.48401876 2.10527392 7.43781975] Ag, [2.313...
# 18       mp-22995  [[ 1.94462322 -1.74755883  1.89344403] Ag, [1....
# 19      mp-558189  [[2.504793 2.504793 0.      ] Ag, [2.504793 0....
# 27      mp-558950  [[ 3.68937808  8.09573714 12.24244424] Ag, [0....
# 33       mp-23548  [[ 2.01581009e+00 -2.21198671e-17  6.28702944e...
# ...           ...                                                ...
# 4549   mp-1189476  [[2.66383663 3.14619771 1.96305558] Nd, [5.413...
# 4550     mp-20852  [[2.78317726 2.5080982  1.93598463] Nd, [5.375...
# 4551   mp-1079171  [[ 2.06204844 -3.65368509  2.08529374] Nd, [2....
# 4552     mp-22106  [[0.04398497 5.1712759  5.70338325] Nd, [2.647...
# 4553    mp-571167  [[ 2.76233118  8.83858657 13.75898303] Nd, [ 6...
#
#       band gaps  theoretical  stable
# 14       0.2964        False   False
# 18       0.7261        False   False
# 19       0.6243        False   False
# 27       0.4985        False   False
# 33       0.0000        False   False
# ...         ...          ...     ...
# 4549     0.0000        False   False
# 4550     1.8980        False    True
# 4551     0.0000        False    True
# 4552     0.0000        False    True
# 4553     0.0000        False    True
#
# [1759 rows x 5 columns]

# %%
real_perovs["stable"] = real_perovs["stable"].astype(int)
# Out:
# C:\Users\Kshitij Vashisth\AppData\Local\Temp\ipykernel_20684\3917787968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_perovs["stable"] = real_perovs["stable"].astype(int)

# %%
real_perovs
# Out:
#      material ids                                          structure  \
# 14     mp-1105645  [[7.48401876 2.10527392 7.43781975] Ag, [2.313...
# 18       mp-22995  [[ 1.94462322 -1.74755883  1.89344403] Ag, [1....
# 19      mp-558189  [[2.504793 2.504793 0.      ] Ag, [2.504793 0....
# 27      mp-558950  [[ 3.68937808  8.09573714 12.24244424] Ag, [0....
# 33       mp-23548  [[ 2.01581009e+00 -2.21198671e-17  6.28702944e...
# ...           ...                                                ...
# 4549   mp-1189476  [[2.66383663 3.14619771 1.96305558] Nd, [5.413...
# 4550     mp-20852  [[2.78317726 2.5080982  1.93598463] Nd, [5.375...
# 4551   mp-1079171  [[ 2.06204844 -3.65368509  2.08529374] Nd, [2....
# 4552     mp-22106  [[0.04398497 5.1712759  5.70338325] Nd, [2.647...
# 4553    mp-571167  [[ 2.76233118  8.83858657 13.75898303] Nd, [ 6...
#
#       band gaps  theoretical  stable
# 14       0.2964        False       0
# 18       0.7261        False       0
# 19       0.6243        False       0
# 27       0.4985        False       0
# 33       0.0000        False       0
# ...         ...          ...     ...
# 4549     0.0000        False       0
# 4550     1.8980        False       1
# 4551     0.0000        False       1
# 4552     0.0000        False       1
# 4553     0.0000        False       1
#
# [1759 rows x 5 columns]

# %% [markdown]
# ## Featurizing data using packages from Matminer

# %% [markdown]
# I chose a completely random feature that can be generated from structure, will be experimenting with lots of different ones. <br>
# Can be found at: https://hackingmaterials.lbl.gov/matminer/featurizer_summary.html

# %%
from matminer.featurizers.structure import XRDPowderPattern
xrd = XRDPowderPattern()

# %%
real_perovs_xrd = xrd.featurize_dataframe(real_perovs, "structure")
# Out:
# XRDPowderPattern:   0%|          | 0/1759 [00:00<?, ?it/s]

# %%
real_perovs_xrd = pd.read_csv('real_perovs_xrd.csv')

# %%
real_perovs_xrd
# Out:
#      material ids                                          structure  \
# 0      mp-1105645  Full Formula (Ag12 S4 Br4)\nReduced Formula: A...
# 1        mp-22995  Full Formula (Ag3 S1 I1)\nReduced Formula: Ag3...
# 2       mp-558189  Full Formula (Ag3 S1 I1)\nReduced Formula: Ag3...
# 3       mp-558950  Full Formula (Ag24 As24 O72)\nReduced Formula:...
# 4        mp-23548  Full Formula (Ag2 Bi2 O6)\nReduced Formula: Ag...
# ...           ...                                                ...
# 1754   mp-1189476  Full Formula (Nd4 Mn4 O12)\nReduced Formula: N...
# 1755     mp-20852  Full Formula (Nd4 Mn4 O12)\nReduced Formula: N...
# 1756   mp-1079171  Full Formula (Nd2 Ni2 Ge6)\nReduced Formula: N...
# 1757     mp-22106  Full Formula (Nd4 Ni4 O12)\nReduced Formula: N...
# 1758    mp-571167  Full Formula (Nd12 Ni12 Sb36)\nReduced Formula...
#
#       band gaps  theoretical  stable         xrd_0         xrd_1  \
# 0        0.2964        False       0  2.478322e-26  7.762754e-23
# 1        0.7261        False       0  2.061098e-37  1.139955e-33
# 2        0.6243        False       0  3.359836e-86  9.774339e-80
# 3        0.4985        False       0  2.928741e-23  5.345314e-20
# 4        0.0000        False       0  4.621298e-32  1.246952e-28
# ...         ...          ...     ...           ...           ...
# 1754     0.0000        False       0  4.024008e-50  1.523183e-45
# 1755     1.8980        False       1  3.017360e-60  2.631816e-55
# 1756     0.0000        False       1  7.766112e-12  5.162759e-10
# 1757     0.0000        False       1  1.314500e-64  2.031345e-59
# 1758     0.0000        False       1  2.723079e-10  1.963165e-08
#
#              xrd_2         xrd_3         xrd_4  ...       xrd_118  \
# 0     1.254368e-19  1.045647e-16  4.496728e-14  ...  5.480407e-07
# 1     3.841217e-30  7.885731e-27  9.862955e-24  ...  4.197247e-03
# 2     1.554275e-73  1.350951e-67  6.418341e-62  ...  4.348214e-04
# 3     4.845123e-17  2.181101e-14  4.876252e-12  ...  2.167607e-03
# 4     2.058293e-25  2.078434e-22  1.283916e-19  ...  3.968101e-03
# ...            ...           ...           ...  ...           ...
# 1754  3.326686e-41  4.192162e-37  3.048112e-33  ...  2.720574e-03
# 1755  1.379515e-50  4.345677e-46  8.227486e-42  ...  3.807744e-03
# 1756  1.982200e-08  4.395421e-07  5.629125e-06  ...  8.509832e-04
# 1757  1.861787e-54  1.012046e-49  3.262827e-45  ...  1.041261e-02
# 1758  7.288055e-07  1.393235e-05  1.371498e-04  ...  1.177471e-03
#
#            xrd_119   xrd_120   xrd_121   xrd_122   xrd_123   xrd_124  \
# 0     6.226729e-08  0.000001  0.000021  0.000183  0.000939  0.002913
# 1     1.812563e-03  0.000485  0.000082  0.000037  0.000210  0.000945
# 2     2.016603e-03  0.005112  0.007084  0.005365  0.002221  0.000503
# 3     2.228740e-03  0.002280  0.002234  0.002503  0.002920  0.002826
# 4     2.866507e-03  0.002318  0.003033  0.004262  0.004524  0.003224
# ...            ...       ...       ...       ...       ...       ...
# 1754  2.849249e-03  0.003757  0.004492  0.004112  0.003207  0.002657
# 1755  3.928954e-03  0.003471  0.002783  0.002942  0.003726  0.004412
# 1756  6.608937e-04  0.000714  0.001633  0.003422  0.004690  0.003991
# 1757  1.126488e-02  0.007685  0.003383  0.001215  0.001344  0.003030
# 1758  1.159504e-03  0.001270  0.001691  0.002334  0.002516  0.002104
#
#        xrd_125   xrd_126       xrd_127
# 0     0.005379  0.005676  3.291362e-03
# 1     0.002605  0.004397  4.545096e-03
# 2     0.000062  0.000004  1.553321e-07
# 3     0.002212  0.001436  7.567850e-04
# 4     0.001471  0.000420  7.436288e-05
# ...        ...       ...           ...
# 1754  0.002230  0.001485  6.783342e-04
# 1755  0.004628  0.003932  2.427809e-03
# 1756  0.002062  0.000636  1.155609e-04
# 1757  0.004591  0.004151  2.227070e-03
# 1758  0.001704  0.001332  7.678724e-04
#
# [1759 rows x 133 columns]

# %%
real_perovs_xrd.to_csv('real_perovs_xrd.csv', index=False)

# %%
y = real_perovs_xrd["stable"].values
X = real_perovs_xrd.drop(["material ids", "structure", "band gaps", "theoretical", "stable"], axis=1)

# %% [markdown]
# ## Making and testing a basic classifying model

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1319, 128), (440, 128), (1319,), (440,))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
stable_classifier = RandomForestClassifier(random_state=42)
stable_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
training_accuracy = stable_classifier.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy:.1f} %')
# Out:
# Accuracy on training data: 100.0 %

# %% [markdown]
# ### might be overfitting.

# %%
testing_accuracy = stable_classifier.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy:.1f} %')
# Out:
# Accuracy on testing data: 67.3 %

# %% [markdown]
# # What next?

# %% [markdown]
# Try different features and different models for predicting stability in these materials first. <br>
# Can move on to stability in other materials or other properties of perovskites once initial models are optimised. <br>

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
predictions = log_reg.predict(X_test)

# %%
training_accuracy_log_reg = log_reg.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy_log_reg:.1f} %')
# Out:
# Accuracy on training data: 60.0 %

# %%
testing_accuracy = log_reg.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy:.1f} %')
# Out:
# Accuracy on testing data: 59.5 %

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_classifier = DecisionTreeClassifier(max_depth=3)
tree_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
predictions_dec_tree = tree_classifier.predict(X_test)

# %%
training_accuracy_dec_tree = tree_classifier.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy_dec_tree:.1f} %')
# Out:
# Accuracy on training data: 68.8 %

# %%
testing_accuracy_dec_tree = tree_classifier.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy:.1f} %')
# Out:
# Accuracy on testing data: 59.5 %

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC

# %%
svm_classifier = SVC(kernel='linear', C=1.0)
svm_classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
predictions_svm = svm_classifier.predict(X_test)

# %%
training_accuracy_svm = svm_classifier.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy_svm:.1f} %')
# Out:
# Accuracy on training data: 58.8 %

# %%
testing_accuracy_svm = svm_classifier.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy_svm:.1f} %')
# Out:
# Accuracy on testing data: 58.6 %

# %% [markdown]
# # K nearest neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k = 5
knn_classifier = KNeighborsClassifier(n_neighbors=k)
knn_classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
predictions_knn = knn_classifier.predict(X_test)

# %%
training_accuracy_knn = knn_classifier.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy_knn:.1f} %')
# Out:
# Accuracy on training data: 77.9 %

# %%
testing_accuracy_knn = knn_classifier.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy_knn:.1f} %')
# Out:
# Accuracy on testing data: 60.9 %

# %% [markdown]
# # Gradient Boosting Machines

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbm_classifier = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
gbm_classifier.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
predictions_gbm = gbm_classifier.predict(X_test)

# %%
training_accuracy_gbm = gbm_classifier.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy_gbm:.1f} %')
# Out:
# Accuracy on training data: 91.6 %

# %%
testing_accuracy_gbm = gbm_classifier.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy_gbm:.1f} %')
# Out:
# Accuracy on testing data: 64.8 %

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada_classifier = AdaBoostClassifier(n_estimators=100, learning_rate=1.0, random_state=42)
ada_classifier.fit(X_train, y_train)
# Out:
# C:\AI\miniforge\envs\spyder\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier(n_estimators=100, random_state=42)

# %%
predictions_ada = ada_classifier.predict(X_test)

# %%
training_accuracy_ada = ada_classifier.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy_ada:.1f} %')
# Out:
# Accuracy on training data: 83.9 %

# %%
testing_accuracy_ada = ada_classifier.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy_ada:.1f} %')
# Out:
# Accuracy on testing data: 60.0 %

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

# %%
xgb_classifier = XGBClassifier(n_estimators=100, max_depth=3, learning_rate=0.1, random_state=42)
xgb_classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
predictions_xgb = xgb_classifier.predict(X_test)

# %%
training_accuracy_xgb = xgb_classifier.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy_xgb:.1f} %')
# Out:
# Accuracy on training data: 90.3 %

# %%
testing_accuracy_xgb = xgb_classifier.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy_xgb:.1f} %')
# Out:
# Accuracy on testing data: 63.2 %

# %% [markdown]
# # Deep Learning

# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# WARNING:tensorflow:From C:\AI\miniforge\envs\spyder\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## F1 score

# %%
from sklearn.metrics import f1_score

# %%
predictions_random_forest = stable_classifier.predict(X_test)

# %%
from sklearn.model_selection import cross_val_predict

# %%
y_train_pred = cross_val_predict(stable_classifier, X_train, y_train, cv=3)

# %%
f1_score(y_train, y_train_pred)
# Out:
# 0.5240761478163494

# %%
y_test_pred = cross_val_predict(stable_classifier, X_test, y_test, cv=3)

# %%
f1_score(y_test, y_test_pred)
# Out:
# 0.44368600682593856

# %%
from sklearn.metrics import confusion_matrix

# %%
conf_matrix = confusion_matrix(y_test, y_test_pred)

# %%
print(conf_matrix)
# Out:
# [[212  46]
#  [117  65]]
