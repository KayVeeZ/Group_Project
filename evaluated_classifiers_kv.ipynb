# %%
import numpy as np
import pandas as pd
from mp_api.client import MPRester
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from matminer.featurizers.structure import DensityFeatures
from matminer.featurizers.structure import StructuralComplexity
from matminer.featurizers.structure import MaximumPackingEfficiency

# %% [markdown]
# ### Perovskites

# %%
with MPRester("EclqWMXn0DY3CAOSELD3xvCjEVhlcEYp") as mpr:
    perovskites = mpr.materials.summary.search(formula=["ABC3"], fields = ["material_id", "structure", "band_gap", "theoretical", "is_stable", "formula_pretty", "composition"])
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/4555 [00:00<?, ?it/s]

# %%
ids = []
for i in range(len(perovskites)):
    single = perovskites[i]
    ids.append(single.material_id)

structures = []
for i in range(len(perovskites)):
    single = perovskites[i]
    structures.append(single.structure)

band_gaps = []
for i in range(len(perovskites)):
    single = perovskites[i]
    band_gaps.append(single.band_gap)

theory = []
for i in range(len(perovskites)):
    single = perovskites[i]
    theory.append(single.theoretical)

stable = []
for i in range(len(perovskites)):
    single = perovskites[i]
    stable.append(single.is_stable)

formula = []
for i in range(len(perovskites)):
    single = perovskites[i]
    formula.append(single.formula_pretty)

composition = []
for i in range(len(perovskites)):
    single = perovskites[i]
    composition.append(single.composition)

perov_df = pd.DataFrame(
    {"material ids": ids,
     "formula": formula,
     "composition": composition,
     "structure": structures,
     "band gaps": band_gaps,
     "theoretical": theory,
     "stable": stable
    })

# %%
perov_df = pd.read_csv('perov_df.csv')

# %%
perov_df
# Out:
#      material ids                                          structure  \
# 0      mp-1183115  Full Formula (Ac1 Al1 O3)\nReduced Formula: Ac...
# 1      mp-1183052  Full Formula (Ac1 B1 O3)\nReduced Formula: AcB...
# 2       mp-866101  Full Formula (Ac1 Cr1 O3)\nReduced Formula: Ac...
# 3       mp-864606  Full Formula (Ac1 Cu1 O3)\nReduced Formula: Ac...
# 4       mp-861502  Full Formula (Ac1 Fe1 O3)\nReduced Formula: Ac...
# ...           ...                                                ...
# 4550     mp-20852  Full Formula (Nd4 Mn4 O12)\nReduced Formula: N...
# 4551   mp-1079171  Full Formula (Nd2 Ni2 Ge6)\nReduced Formula: N...
# 4552     mp-22106  Full Formula (Nd4 Ni4 O12)\nReduced Formula: N...
# 4553    mp-571167  Full Formula (Nd12 Ni12 Sb36)\nReduced Formula...
# 4554   mp-1186312  Full Formula (Nd1 Np1 O3)\nReduced Formula: Nd...
#
#       band gaps  theoretical  stable
# 0        4.1024         True    True
# 1        0.8071         True   False
# 2        2.0031         True    True
# 3        0.0000         True    True
# 4        0.9888         True    True
# ...         ...          ...     ...
# 4550     1.8980        False    True
# 4551     0.0000        False    True
# 4552     0.0000        False    True
# 4553     0.0000        False    True
# 4554     0.0000         True   False
#
# [4555 rows x 5 columns]

# %%
real_perovs = perov_df[perov_df["theoretical"]==False]

# %%
real_perovs["stable"] = real_perovs["stable"].astype(int)
# Out:
# C:\Users\Kshitij Vashisth\AppData\Local\Temp\ipykernel_13944\3917787968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_perovs["stable"] = real_perovs["stable"].astype(int)

# %%
perovs_feat = real_perovs

# %%
densityf = DensityFeatures()
strcomp = StructuralComplexity()
mpe = MaximumPackingEfficiency()

# %%
perovs_feat = densityf.featurize_dataframe(perovs_feat, "structure")
# Out:
# DensityFeatures:   0%|          | 0/1759 [00:00<?, ?it/s]

# %%
perovs_feat = strcomp.featurize_dataframe(perovs_feat, "structure")
# Out:
# StructuralComplexity:   0%|          | 0/1759 [00:00<?, ?it/s]

# %%
perovs_feat = mpe.featurize_dataframe(perovs_feat, "structure")
# Out:
# MaximumPackingEfficiency:   0%|          | 0/1759 [00:00<?, ?it/s]

# %%
perovs_feat.to_csv('perovs_feat.csv')

# %%
perovs_feat =  pd.read_csv('perovs_feat.csv')

# %%
y = perovs_feat["stable"].values
X = perovs_feat.drop(["Unnamed: 0","material ids", "formula", "composition", "structure", "band gaps", "theoretical", "stable"], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

stable_classifier = RandomForestClassifier(random_state=0)
stable_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
perovs_feat
# Out:
#       Unnamed: 0 material ids  formula     composition  \
# 0             14   mp-1105645   Ag3SBr     Ag12 S4 Br4
# 1             18     mp-22995    Ag3SI       Ag3 S1 I1
# 2             19    mp-558189    Ag3SI       Ag3 S1 I1
# 3             27    mp-558950   AgAsO3   Ag24 As24 O72
# 4             33     mp-23548   AgBiO3      Ag2 Bi2 O6
# ...          ...          ...      ...             ...
# 1754        4549   mp-1189476   NdMnO3     Nd4 Mn4 O12
# 1755        4550     mp-20852   NdMnO3     Nd4 Mn4 O12
# 1756        4551   mp-1079171  NdNiGe3     Nd2 Ni2 Ge6
# 1757        4552     mp-22106   NdNiO3     Nd4 Ni4 O12
# 1758        4553    mp-571167  NdNiSb3  Nd12 Ni12 Sb36
#
#                                               structure  band gaps  \
# 0     Full Formula (Ag12 S4 Br4)\nReduced Formula: A...     0.2964
# 1     Full Formula (Ag3 S1 I1)\nReduced Formula: Ag3...     0.7261
# 2     Full Formula (Ag3 S1 I1)\nReduced Formula: Ag3...     0.6243
# 3     Full Formula (Ag24 As24 O72)\nReduced Formula:...     0.4985
# 4     Full Formula (Ag2 Bi2 O6)\nReduced Formula: Ag...     0.0000
# ...                                                 ...        ...
# 1754  Full Formula (Nd4 Mn4 O12)\nReduced Formula: N...     0.0000
# 1755  Full Formula (Nd4 Mn4 O12)\nReduced Formula: N...     1.8980
# 1756  Full Formula (Nd2 Ni2 Ge6)\nReduced Formula: N...     0.0000
# 1757  Full Formula (Nd4 Ni4 O12)\nReduced Formula: N...     0.0000
# 1758  Full Formula (Nd12 Ni12 Sb36)\nReduced Formula...     0.0000
#
#       theoretical  stable   density        vpa  packing fraction  \
# 0           False       0  5.967646  24.240276          0.511803
# 1           False       0  6.576090  24.371110          0.551101
# 2           False       0  6.373934  25.144066          0.534159
# 3           False       0  5.320520  14.405829          0.364328
# 4           False       0  7.836022  15.463008          0.478935
# ...           ...     ...       ...        ...               ...
# 1754        False       0  6.679080  12.290589          0.662787
# 1755        False       1  6.966900  11.782834          0.691349
# 1756        False       1  7.486044  18.670657          0.657412
# 1757        False       1  7.555034  11.030659          0.716950
# 1758        False       1  7.774742  24.272031          0.619132
#
#       structural complexity per atom  structural complexity per cell  \
# 0                           2.521928                       50.438562
# 1                           1.370951                        6.854753
# 2                           1.370951                        6.854753
# 3                           4.906891                      588.826871
# 4                           1.370951                       13.709506
# ...                              ...                             ...
# 1754                        2.521928                       50.438562
# 1755                        1.921928                       38.438562
# 1756                        2.321928                       23.219281
# 1757                        1.921928                       38.438562
# 1758                        3.240224                      194.413436
#
#       max packing efficiency
# 0                   0.394708
# 1                   0.409055
# 2                   0.446920
# 3                   0.244454
# 4                   0.365136
# ...                      ...
# 1754                0.383291
# 1755                0.392994
# 1756                0.457677
# 1757                0.402676
# 1758                0.492133
#
# [1759 rows x 14 columns]

# %%
perovs_feat.drop(["Unnamed: 0","material ids", "formula", "composition", "structure", "band gaps", "theoretical", "stable"], axis=1)
# Out:
#        density        vpa  packing fraction  structural complexity per atom  \
# 0     5.967646  24.240276          0.511803                        2.521928
# 1     6.576090  24.371110          0.551101                        1.370951
# 2     6.373934  25.144066          0.534159                        1.370951
# 3     5.320520  14.405829          0.364328                        4.906891
# 4     7.836022  15.463008          0.478935                        1.370951
# ...        ...        ...               ...                             ...
# 1754  6.679080  12.290589          0.662787                        2.521928
# 1755  6.966900  11.782834          0.691349                        1.921928
# 1756  7.486044  18.670657          0.657412                        2.321928
# 1757  7.555034  11.030659          0.716950                        1.921928
# 1758  7.774742  24.272031          0.619132                        3.240224
#
#       structural complexity per cell  max packing efficiency
# 0                          50.438562                0.394708
# 1                           6.854753                0.409055
# 2                           6.854753                0.446920
# 3                         588.826871                0.244454
# 4                          13.709506                0.365136
# ...                              ...                     ...
# 1754                       50.438562                0.383291
# 1755                       38.438562                0.392994
# 1756                       23.219281                0.457677
# 1757                       38.438562                0.402676
# 1758                      194.413436                0.492133
#
# [1759 rows x 6 columns]

# %%
from sklearn.model_selection import GridSearchCV
# Define the hyperparameter grid
param_grid = {
    'n_estimators': [50, 100, 150],  # Number of trees in the forest
    'max_depth': [None, 3, 5],      # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4]     # Minimum number of samples required to be at a leaf node
}

# %%
grid_search = GridSearchCV(estimator=stable_classifier, param_grid=param_grid, cv=5, scoring='f1', verbose=1, n_jobs=-1)
# Perform grid search
grid_search.fit(X_train, y_train)

# Get the best parameters and the best F1 score
best_params = grid_search.best_params_
best_f1_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best F1 Score:", best_f1_score)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# Best F1 Score: 0.628827372772919

# %%
best_rf_model = grid_search.best_estimator_

# %%
training_accuracy = best_rf_model.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy:.1f} %')
testing_accuracy = best_rf_model.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy:.1f} %')
# Out:
# Accuracy on training data: 98.4 %
# Accuracy on testing data: 70.9 %

# %%
y_train_pred = best_rf_model.predict(X_train)
y_test_pred = best_rf_model.predict(X_test)
conf_matrix_train = confusion_matrix(y_train, y_train_pred)
conf_matrix_test = confusion_matrix(y_test, y_test_pred)

# %%
print(f"F1 score for the training set is: {f1_score(y_train, y_train_pred)}")
print(f"F1 score for the test set is: {f1_score(y_test, y_test_pred)}")
print(f"Confusion matrix for reference for train:\n {conf_matrix_train}")
print(f"Confusion matrix for reference for test:\n {conf_matrix_test}")
# Out:
# F1 score for the training set is: 0.981549815498155
# F1 score for the test set is: 0.6350148367952523
# Confusion matrix for reference for train:
#  [[767   8]
#  [ 12 532]]
# Confusion matrix for reference for test:
#  [[210  48]
#  [ 75 107]]

# %%
training_accuracy = stable_classifier.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy:.1f} %')
testing_accuracy = stable_classifier.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy:.1f} %')
# Out:
# Accuracy on training data: 100.0 %
# Accuracy on testing data: 72.2 %

# %% [markdown]
# ### Using Regularization

# %%
from sklearn.preprocessing import StandardScaler
# Feature scaling (important for regularization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# This method is for Logistic Regression, please ignore.

# %% [markdown]
# ## Evaluating the classifier

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

# %%
y_train_pred = cross_val_predict(stable_classifier, X_train, y_train, cv=3)
y_test_pred = cross_val_predict(stable_classifier, X_test, y_test, cv=3)
conf_matrix_train = confusion_matrix(y_train, y_train_pred)
conf_matrix_test = confusion_matrix(y_test, y_test_pred)

# %%
y_train_pred = stable_classifier.predict(X_train)
y_test_pred = stable_classifier.predict(X_test)
conf_matrix_train = confusion_matrix(y_train, y_train_pred)
conf_matrix_test = confusion_matrix(y_test, y_test_pred)

# %%
print(f"F1 score for the training set is: {f1_score(y_train, y_train_pred):.3f}")
print(f"F1 score for the test set is: {f1_score(y_test, y_test_pred):.3f}")
print(f"Confusion matrix for reference for train:\n {conf_matrix_train}")
print(f"Confusion matrix for reference for test:\n {conf_matrix_test}")
# Out:
# F1 score for the training set is: 1.000
# F1 score for the test set is: 0.623
# Confusion matrix for reference for train:
#  [[826   0]
#  [  0 581]]
# Confusion matrix for reference for test:
#  [[173  34]
#  [ 64  81]]

# %% [markdown]
# ## Dumping the model for deployment

# %%
from joblib import dump, load

# %%
dump(stable_classifier, 'perovskites.joblib')
# Out:
# ['perovskites.joblib']

# %% [markdown]
# ### III-V Semiconductors

# %%
with MPRester("EclqWMXn0DY3CAOSELD3xvCjEVhlcEYp") as mpr:
    iii_v = mpr.materials.summary.search(chemsys=["Al-N", "Al-P", "Al-As", "Al-Sb",
                                      "Ga-N", "Ga-P", "Ga-As", "Ga-Sb"
                                      "In-N", "In-P", "In-As", "In-Sb"], 
                              fields = ["material_id", "structure", "band_gap", "theoretical", "is_stable", "formula_pretty", "composition"])
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/117 [00:00<?, ?it/s]

# %%
ids = []
for i in range(len(iii_v)):
    single = iii_v[i]
    ids.append(single.material_id)

structures = []
for i in range(len(iii_v)):
    single = iii_v[i]
    structures.append(single.structure)

band_gaps = []
for i in range(len(iii_v)):
    single = iii_v[i]
    band_gaps.append(single.band_gap)

theory = []
for i in range(len(iii_v)):
    single = iii_v[i]
    theory.append(single.theoretical)

stable = []
for i in range(len(iii_v)):
    single = iii_v[i]
    stable.append(single.is_stable)

formula = []
for i in range(len(iii_v)):
    single = iii_v[i]
    formula.append(single.formula_pretty)

composition = []
for i in range(len(iii_v)):
    single = iii_v[i]
    composition.append(single.composition)

iii_v_df = pd.DataFrame(
    {"material ids": ids,
     "formula": formula,
     "composition": composition,
     "structure": structures,
     "band gaps": band_gaps,
     "theoretical": theory,
     "stable": stable
    })

# %%
iii_v_feat = iii_v_df

# %%
iii_v_feat = densityf.featurize_dataframe(iii_v_feat, "structure")
# Out:
# DensityFeatures:   0%|          | 0/117 [00:00<?, ?it/s]

# %%
iii_v_feat = strcomp.featurize_dataframe(iii_v_feat, "structure")
# Out:
# StructuralComplexity:   0%|          | 0/117 [00:00<?, ?it/s]

# %%
iii_v_feat = mpe.featurize_dataframe(iii_v_feat, "structure")
# Out:
# MaximumPackingEfficiency:   0%|          | 0/117 [00:00<?, ?it/s]

# %%
iii_v_feat.to_csv('iii_v_feat.csv')

# %%
iii_v_feat = pd.read_csv('iii_v_feat.csv')

# %%
y = iii_v_feat["stable"].values
X = iii_v_feat.drop(["material ids", "formula", "composition", "structure", "band gaps", "theoretical", "stable"], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=0)

stable_classifier = RandomForestClassifier(random_state=42)
stable_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
training_accuracy = stable_classifier.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy:.1f} %')
testing_accuracy = stable_classifier.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy:.1f} %')
# Out:
# Accuracy on training data: 100.0 %
# Accuracy on testing data: 96.7 %

# %% [markdown]
# ## Evaluating again

# %%
y_train_pred = cross_val_predict(stable_classifier, X_train, y_train, cv=3)
y_test_pred = cross_val_predict(stable_classifier, X_test, y_test, cv=3)
conf_matrix_train = confusion_matrix(y_train, y_train_pred)
conf_matrix_test = confusion_matrix(y_test, y_test_pred)

# %%
y_train_pred = stable_classifier.predict(X_train)
y_test_pred = stable_classifier.predict(X_test)
conf_matrix_train = confusion_matrix(y_train, y_train_pred)
conf_matrix_test = confusion_matrix(y_test, y_test_pred)

# %%
print(f"F1 score for the training set is: {f1_score(y_train, y_train_pred)}")
print(f"F1 score for the test set is: {f1_score(y_test, y_test_pred)}")
print(f"Confusion matrix for reference for train:\n {conf_matrix_train}")
print(f"Confusion matrix for reference for test:\n {conf_matrix_test}")
# Out:
# F1 score for the training set is: 1.0
# F1 score for the test set is: 0.8
# Confusion matrix for reference for train:
#  [[80  0]
#  [ 0  7]]
# Confusion matrix for reference for test:
#  [[27  0]
#  [ 1  2]]

# %% [markdown]
# ### II-VI Semiconductors

# %%
with MPRester("EclqWMXn0DY3CAOSELD3xvCjEVhlcEYp") as mpr:
    ii_vi = mpr.materials.summary.search(chemsys=["Zn-S", "Zn-Se", "Zn-Te",
                                        "Cd-S", "Cd-Se", "Cd-Te"], 
                               fields = ["material_id", "structure", "band_gap", "theoretical", "is_stable", "formula_pretty", "composition"])
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/185 [00:00<?, ?it/s]

# %%
ids = []
for i in range(len(ii_vi)):
    single = ii_vi[i]
    ids.append(single.material_id)

structures = []
for i in range(len(ii_vi)):
    single = ii_vi[i]
    structures.append(single.structure)

band_gaps = []
for i in range(len(ii_vi)):
    single = ii_vi[i]
    band_gaps.append(single.band_gap)

theory = []
for i in range(len(ii_vi)):
    single = ii_vi[i]
    theory.append(single.theoretical)

stable = []
for i in range(len(ii_vi)):
    single = ii_vi[i]
    stable.append(single.is_stable)

formula = []
for i in range(len(ii_vi)):
    single = ii_vi[i]
    formula.append(single.formula_pretty)

composition = []
for i in range(len(ii_vi)):
    single = ii_vi[i]
    composition.append(single.composition)

ii_vi_df = pd.DataFrame(
    {"material ids": ids,
     "formula": formula,
     "composition": composition,
     "structure": structures,
     "band gaps": band_gaps,
     "theoretical": theory,
     "stable": stable
    })

# %%
ii_vi_feat = ii_vi_df

# %%
ii_vi_feat = densityf.featurize_dataframe(ii_vi_feat, "structure")
# Out:
# DensityFeatures:   0%|          | 0/185 [00:00<?, ?it/s]

# %%
ii_vi_feat = strcomp.featurize_dataframe(ii_vi_feat, "structure")
# Out:
# StructuralComplexity:   0%|          | 0/185 [00:00<?, ?it/s]

# %%
ii_vi_feat = mpe.featurize_dataframe(ii_vi_feat, "structure")
# Out:
# MaximumPackingEfficiency:   0%|          | 0/185 [00:00<?, ?it/s]

# %%
ii_vi_feat.to_csv("ii_vi_feat.csv")

# %%
ii_vi_feat =  pd.read_csv('ii_vi_feat.csv')

# %%
y = ii_vi_feat["stable"].values
X = ii_vi_feat.drop(["material ids", "formula", "composition", "structure", "band gaps", "theoretical", "stable"], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=0)

stable_classifier = RandomForestClassifier(random_state=42,class_weight='balanced')
stable_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
from sklearn.ensemble import BaggingClassifier
bagging_rf = BaggingClassifier(estimator=stable_classifier, random_state=42)
bagging_rf.fit(X_train, y_train)
# Out:
# BaggingClassifier(estimator=RandomForestClassifier(class_weight='balanced',
#                                                    random_state=42),
#                   random_state=42)

# %%
training_accuracy = stable_classifier.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy:.1f} %')
testing_accuracy = stable_classifier.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy:.1f} %')
# Out:
# Accuracy on training data: 100.0 %
# Accuracy on testing data: 93.6 %

# %%
training_accuracy = bagging_rf.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy:.1f} %')
testing_accuracy = bagging_rf.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy:.1f} %')
# Out:
# Accuracy on training data: 98.6 %
# Accuracy on testing data: 93.6 %

# %% [markdown]
# ## Evaluating

# %%
y_train_pred = cross_val_predict(stable_classifier, X_train, y_train, cv=3)
y_test_pred = cross_val_predict(stable_classifier, X_test, y_test, cv=2)
conf_matrix_train = confusion_matrix(y_train, y_train_pred)
conf_matrix_test = confusion_matrix(y_test, y_test_pred)

# %%
y_train_pred = bagging_rf.predict(X_train)
y_test_pred = bagging_rf.predict(X_test)
conf_matrix_train = confusion_matrix(y_train, y_train_pred)
conf_matrix_test = confusion_matrix(y_test, y_test_pred)

# %%
print(f"F1 score for the training set is: {f1_score(y_train, y_train_pred)}")
print(f"F1 score for the test set is: {f1_score(y_test, y_test_pred)}")
print(f"Confusion matrix for reference for train:\n {conf_matrix_train}")
print(f"Confusion matrix for reference for test:\n {conf_matrix_test}")
# Out:
# F1 score for the training set is: 0.8
# F1 score for the test set is: 0.0
# Confusion matrix for reference for train:
#  [[132   0]
#  [  2   4]]
# Confusion matrix for reference for test:
#  [[44  1]
#  [ 2  0]]

# %%
pd.DataFrame(y).shape
# Out:
# (185, 1)

# %%
pd.DataFrame(X).value_counts()
# Out:
# Unnamed: 0  density   vpa        packing fraction  structural complexity per atom  structural complexity per cell  max packing efficiency
# 0           6.408285  17.826874  0.522927          0.811278                        3.245112                        0.740480                  1
# 127         4.138627  19.554718  0.370621          2.584963                        15.509775                       0.339764                  1
# 118         4.134738  19.573113  0.370273          5.700440                        296.422865                      0.339804                  1
# 119         4.140940  19.543795  0.370828          5.584963                        268.078200                      0.339885                  1
# 120         4.138446  19.555578  0.370605          3.000000                        24.000000                       0.339778                  1
#                                                                                                                                             ..
# 64          3.485125  23.221463  0.312099          6.643856                        664.385619                      0.263272                  1
# 65          3.318305  24.388864  0.297160          6.643856                        664.385619                      0.250005                  1
# 66          3.411736  23.720969  0.305527          6.643856                        664.385619                      0.259153                  1
# 67          3.507318  23.074525  0.314086          6.643856                        664.385619                      0.265750                  1
# 184         4.094112  17.513327  0.355607          0.918296                        11.019550                       0.335228                  1
# Length: 185, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV
# Define the hyperparameter grid
param_grid = {
    'n_estimators': [50, 100, 150],  # Number of trees in the forest
    'max_depth': [None, 3, 5],      # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4]     # Minimum number of samples required to be at a leaf node
}

# %%
grid_search = GridSearchCV(estimator=stable_classifier, param_grid=param_grid, cv=5, scoring='f1', verbose=1, n_jobs=-1)

# %%
# Perform grid search
grid_search.fit(X_train, y_train)

# Get the best parameters and the best F1 score
best_params = grid_search.best_params_
best_f1_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best F1 Score:", best_f1_score)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# Best F1 Score: 0.5

# %%
best_rf_model = grid_search.best_estimator_

# %%
training_accuracy = best_rf_model.score(X_train, y_train) * 100
print(f'Accuracy on training data: {training_accuracy:.1f} %')
testing_accuracy = best_rf_model.score(X_test, y_test) * 100
print(f'Accuracy on testing data: {testing_accuracy:.1f} %')
# Out:
# Accuracy on training data: 94.9 %
# Accuracy on testing data: 95.7 %

# %%
y_train_pred = best_rf_model.predict(X_train)
y_test_pred = best_rf_model.predict(X_test)
conf_matrix_train = confusion_matrix(y_train, y_train_pred)
conf_matrix_test = confusion_matrix(y_test, y_test_pred)

# %%
print(f"F1 score for the training set is: {f1_score(y_train, y_train_pred)}")
print(f"F1 score for the test set is: {f1_score(y_test, y_test_pred)}")
print(f"Confusion matrix for reference for train:\n {conf_matrix_train}")
print(f"Confusion matrix for reference for test:\n {conf_matrix_test}")
# Out:
# F1 score for the training set is: 0.631578947368421
# F1 score for the test set is: 0.5
# Confusion matrix for reference for train:
#  [[125   7]
#  [  0   6]]
# Confusion matrix for reference for test:
#  [[44  1]
#  [ 1  1]]

# %%
print(pd.__version__)
# Out:
# 1.5.3

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.4.1.post1

# %%
perovs_feat = pd.read_csv("perovs_feat.csv")

# %%
# %%capture
import re

# Function to check for repetitive elements in a chemical formula
def check_repetitive_elements(formula):
    elements = re.findall('[A-Z][a-z]?', formula)  # Extract elements from the formula
    element_count = {}
    for element in elements:
        if element in element_count:
            element_count[element] += 1
        else:
            element_count[element] = 1

    repetitive_elements = [element for element, count in element_count.items() if count > 1]
    return repetitive_elements

# Function to check if each element is matched with other elements
def check_matching_elements(formula):
    elements = re.findall('[A-Z][a-z]?', formula)  # Extract elements from the formula
    unique_elements = set(elements)
    matched = all(len(element) == 1 for element in unique_elements)
    return matched

# Iterate through each material in the dataframe
for index, row in perovs_feat.iterrows():
    chemical_formula = row['formula']

    # Check for repetitive elements
    repetitive_elements = check_repetitive_elements(chemical_formula)
    if repetitive_elements:
        print(f"Material '{chemical_formula}' has repetitive elements: {', '.join(repetitive_elements)}")

    # Check if each element is matched with other elements
    matched_elements = check_matching_elements(chemical_formula)
    if not matched_elements:
        print(f"Material '{chemical_formula}' has unmatched elements.")

    # You can add further processing or logging here as per your requirement

# %%
# Function to check for repetitive elements in a chemical formula
def check_repetitive_elements(formula):
    elements = re.findall('[A-Z][a-z]?', formula)  # Extract elements from the formula
    element_count = {}
    for element in elements:
        if element in element_count:
            element_count[element] += 1
        else:
            element_count[element] = 1

    repetitive_elements = [element for element, count in element_count.items() if count > 1]
    return repetitive_elements

# Function to check if each element is matched with other elements
def check_matching_elements(formula):
    elements = re.findall('[A-Z][a-z]?', formula)  # Extract elements from the formula
    unique_elements = set(elements)
    matched = all(len(element) == 1 for element in unique_elements)
    return matched

# Iterate through each material in the dataframe
for index, row in perovs_feat.iterrows():
    chemical_formula = str(row[0])  # Ensure the value is treated as string

    # Remove numbers from the formula
    chemical_formula = re.sub(r'\d+', '', chemical_formula)

    # Check for repetitive elements
    repetitive_elements = check_repetitive_elements(chemical_formula)
    if repetitive_elements:
        print(f"Formula '{chemical_formula}' has repetitive elements: {', '.join(repetitive_elements)}")

    # Check if each element is matched with other elements
    matched_elements = check_matching_elements(chemical_formula)
    if not matched_elements:
        print(f"Formula '{chemical_formula}' has unmatched elements.")

# %%
perovs_feat["formula"].unique()
# Out:
# array(['Ag3SBr', 'Ag3SI', 'AgAsO3', ..., 'NdNiGe3', 'NdNiO3', 'NdNiSb3'],
#       dtype=object)

# %%
from collections import Counter

# Sample list of chemical formulas
chemical_formulas = [
    "H2O",
    "H2O2",
    "CH4",
    "C6H12O6",
    "NaCl",
    "C6H12O6",
    "CH3OH",
    "Na2SO4"
]

# Function to check for repetitive elements across all formulas
def check_repetitive_elements(formulas):
    all_elements = []
    repetitive_elements = []
    
    # Iterate over each formula
    for formula in formulas:
        # Extract elements from the formula using regular expression
        elements = re.findall('[A-Z][a-z]*', formula)
        all_elements.extend(elements)
    
    # Count occurrences of each element
    element_counts = Counter(all_elements)
    
    # Identify which elements are repeated across different formulas
    for element, count in element_counts.items():
        if count > 1:
            repetitive_elements.append(element)
    
    return repetitive_elements

# Check for repetitive elements across all formulas
repetitive_elements = check_repetitive_elements(chemical_formulas)
print("Repetitive Elements:", repetitive_elements)
# Out:
# Repetitive Elements: ['H', 'O', 'C', 'Na']

# %%
from collections import Counter

# Sample list of chemical formulas
chemical_formulas = perovs_feat["formula"].unique()

# Function to check for repetitive elements across all formulas
def check_repetitive_elements(formulas):
    all_elements = []
    repetitive_elements = {}
    
    # Iterate over each formula
    for formula in formulas:
        # Extract elements from the formula using regular expression
        elements = re.findall('[A-Z][a-z]*', formula)
        all_elements.extend(elements)
    
    # Count occurrences of each element
    element_counts = Counter(all_elements)
    
    # Identify which elements are repeated across different formulas
    for element, count in element_counts.items():
        if count > 1:
            repetitive_elements[element] = [formula for formula in formulas if element in formula]
    
    return repetitive_elements

# Check for repetitive elements across all formulas
repetitive_elements = check_repetitive_elements(chemical_formulas)
print("Repetitive Elements and their matching formulas:")
for element, formulas in repetitive_elements.items():
    print(f"{element}: {formulas}")
    print(f'{element} has {len(formulas)} repetitions')
    print('\n\n')
# Out:
# Repetitive Elements and their matching formulas:
# Ag: ['Ag3SBr', 'Ag3SI', 'AgAsO3', 'AgBiO3', 'AgClO3', 'AgIO3', 'AgNO3', 'AgPO3', 'AgPS3', 'AgPd3Se', 'AgSbO3', 'AgSe3I', 'AgTe3I', 'AgTeO3', 'CsAgCl3', 'CsAgF3', 'CuAgF3', 'KAgF3', 'VAgO3', 'ZnAgF3', 'RbAgF3', 'TaAgO3', 'TaAgS3', 'Mn3AgN', 'NbAgO3']
# Ag has 25 repetitions
#
#
#
# S: ['Ag3SBr', 'Ag3SI', 'AgPS3', 'AgPd3Se', 'AgSbO3', 'AgSe3I', 'AlSBr3', 'AlSiP3', 'Ba3SbN', 'Ba3SnO', 'BaBiSe3', 'BaCaSn3', 'BaGeS3', 'BaHfS3', 'BaNiSn3', 'BaPS3', 'BaPSe3', 'BaSbTe3', 'BaSeO3', 'BaSi3Pd', 'BaSi3Pt', 'BaSiO3', 'BaSn3Au', 'BaSn3Pd', 'BaSn3Pt', 'BaSnO3', 'BaSnS3', 'BaTaS3', 'BaTaSe3', 'BaTeS3', 'BaTiS3', 'BaTiSe3', 'BaUS3', 'BaVS3', 'BaVSe3', 'BaZrS3', 'BaZrSe3', 'CS3N', 'Ca3SbN', 'Ca3SiO', 'Ca3SnN', 'Ca3SnO', 'CaHfS3', 'CaPS3', 'CaPSe3', 'CaSeO3', 'CaSi3Ir', 'CaSi3Pt', 'CaSiO3', 'CaSnO3', 'CaZrS3', 'CdPS3', 'CdPSe3', 'CdSO3', 'CdSeO3', 'CdSiO3', 'CdSnO3', 'Ce3SnC', 'CeBS3', 'CeCoSb3', 'CeCrS3', 'CeCrSe3', 'CeDyS3', 'CeErS3', 'CeLuS3', 'CeNiSb3', 'CeSb3Pd', 'CeScO3', 'CeScS3', 'CeSi3Ir', 'CeSi3Os', 'CeSi3Rh', 'CeSi3Ru', 'CeSiAs3', 'CeSiP3', 'CeSn3Ru', 'CeTmS3', 'Co3SnC', 'CoPS3', 'CoSeO3', 'CoSiO3', 'Cr3SnN', 'CrGaSe3', 'CrPSe3', 'CrSbS3', 'CrSbSe3', 'CrSiTe3', 'CsAuSe3', 'CsBSe3', 'CsGaS3', 'CsGaSe3', 'CsPS3', 'CsSO3', 'CsScCl3', 'CsSiTe3', 'CsSmCl3', 'CsSnBr3', 'CsSnCl3', 'CsSnF3', 'CsSnI3', 'CsSnS3', 'CsSnSe3', 'CsSrF3', 'CsTeSe3', 'Cu3SnAu', 'CuPS3', 'CuSe3Br', 'CuSe3I', 'CuSeO3', 'CuSiO3', 'Dy3SnC', 'DyScO3', 'DySi3Ir', 'Er3SnC', 'ErScS3', 'ErSi3Ni', 'EuGeS3', 'EuHfS3', 'EuPS3', 'EuPSe3', 'EuScO3', 'EuSi3Ir', 'EuSi3Rh', 'EuZrS3', 'EuZrSe3', 'Fe3SnC', 'FePS3', 'FePSe3', 'FeSO3', 'FeSiO3', 'GdCoSi3', 'GdScO3', 'GdScS3', 'GdSi3Ir', 'GePbS3', 'GePdS3', 'H3CS', 'H3CSe', 'HS3N', 'HfPbS3', 'HfSnS3', 'HgPS3', 'HgPSe3', 'HgSN3', 'HgSeO3', 'Ho3SnC', 'HoScO3', 'HoScS3', 'HoSi3Ir', 'InGaS3', 'InSbS3', 'InSiTe3', 'KPS3', 'KPSe3', 'KSO3', 'KSbO3', 'KSiH3', 'KSiO3', 'KSnF3', 'KSnN3', 'TiGeS3', 'TlBS3', 'TlBSe3', 'TlPS3', 'TlSbO3', 'Tm3SnC', 'UCoSe3', 'UCrS3', 'UCrSe3', 'UFeS3', 'UFeSe3', 'UMnSe3', 'UNiS3', 'UNiSe3', 'UPdSe3', 'URhS3', 'URuS3', 'USi3Ir', 'UVSe3', 'VPS3', 'Y3SnC', 'YScO3', 'YSi3Ir', 'YSi3Ni', 'ZnPS3', 'ZnSeO3', 'ZnSiO3', 'ZnSnO3', 'ZrPbS3', 'ZrSnS3', 'NdScO3', 'NdSi3Ir', 'NdSi3Os', 'NdSi3Rh', 'NdSi3Ru', 'NdSn3Ru', 'NdTmS3', 'NiPS3', 'NiPSe3', 'NiSeO3', 'PPbSe3', 'PbSO3', 'PbSeO3', 'PdSeO3', 'Pr3SnC', 'PrBS3', 'PrCoSb3', 'PrErS3', 'PrFeSb3', 'PrLuSe3', 'PrNiSb3', 'PrScO3', 'PrSiAs3', 'PrSiP3', 'PrSn3Ru', 'PrTmS3', 'RbBS3', 'RbBSe3', 'RbPS3', 'RbPSe3', 'RbSO3', 'RbSeO3', 'RbSnF3', 'RbSnI3', 'SNO3', 'SbAsO3', 'Sc3AlC', 'Sc3BPb', 'Sc3GaC', 'Sc3InB', 'Sc3InC', 'Sc3InN', 'Sc3PbC', 'Sc3SnB', 'Sc3SnC', 'Sc3TlB', 'Sc3TlC', 'ScAlO3', 'ScBIr3', 'ScBO3', 'ScBRh3', 'ScBiO3', 'ScCo3C', 'ScCrO3', 'ScIr3C', 'ScMnO3', 'ScRh3C', 'ScRhO3', 'ScRu3C', 'ScSi3Ni', 'ScUS3', 'SiH3F', 'SiH3I', 'SiPbO3', 'Sm3AlC', 'Sm3AlN', 'Sm3GaC', 'Sm3InC', 'Sm3InN', 'Sm3PbC', 'Sm3SnC', 'Sm3TlC', 'SmAlO3', 'SmBO3', 'SmBPd3', 'SmBRh3', 'SmBS3', 'SmCoO3', 'SmCoSb3', 'SmCoSi3', 'SmCrGe3', 'SmCrO3', 'SmCrS3', 'SmFeO3', 'SmFeSb3', 'SmMnO3', 'SmNiGe3', 'SmNiO3', 'SmNiSb3', 'SmRh3C', 'SmRhO3', 'SmScO3', 'SmSi3Ir', 'SmSi3Ni', 'SmSi3Os', 'SmSi3Rh', 'SmSn3Ru', 'SmTiO3', 'SmVO3', 'SnCCl3', 'SnGeS3', 'SnHgO3', 'SnNF3', 'SnPO3', 'SnPS3', 'SnPSe3', 'SnPbO3', 'SnPbS3', 'SnPt3C', 'Sr3BiN', 'Sr3GeO', 'Sr3PbO', 'Sr3SbN', 'Sr3SiO', 'Sr3SnO', 'SrAlH3', 'SrBO3', 'SrBiO3', 'SrBiSe3', 'SrCO3', 'SrCeO3', 'SrCoO3', 'SrCrO3', 'SrFeO3', 'SrGa3Pd', 'SrGe3Ir', 'SrGe3Pd', 'SrGe3Pt', 'SrGeAu3', 'SrGeO3', 'SrHfO3', 'SrHfS3', 'SrIrO3', 'SrLiH3', 'SrMgIn3', 'SrMnO3', 'SrMoO3', 'SrNbO3', 'SrNiSn3', 'SrOsO3', 'SrPS3', 'SrPSe3', 'SrPbO3', 'SrPrO3', 'SrRuO3', 'SrSbSe3', 'SrSeO3', 'SrSi3Au', 'SrSi3Ni', 'SrSiO3', 'SrSn3Pd', 'SrSnO3', 'SrSnS3', 'SrTbO3', 'SrTcO3', 'SrTeO3', 'SrTiO3', 'SrTiS3', 'SrVO3', 'SrZrO3', 'SrZrS3', 'SrZrSe3', 'TaAgS3', 'TaCuS3', 'TaSnO3', 'TaTlS3', 'TaTlSe3', 'Tb3SnC', 'TbBS3', 'TbCoSi3', 'TbFeSb3', 'TbScO3', 'TbSi3Ir', 'TbSi3Rh', 'ThCoSi3', 'ThCrS3', 'ThCrSe3', 'ThMnSe3', 'ThSi3Ir', 'ThSi3Os', 'ThSi3Rh', 'ThSi3Ru', 'Ti3SnH', 'LaCoSb3', 'LaCoSi3', 'LaCrS3', 'LaCrSb3', 'LaCrSe3', 'LaErS3', 'LaGaS3', 'LaHoS3', 'LaNiSb3', 'LaScO3', 'LaSi3Ir', 'LaSi3Os', 'LaSi3Rh', 'LaSi3Ru', 'LaSiAs3', 'LaSn3Ru', 'LaTmS3', 'LaYS3', 'LiSbO3', 'LiScI3', 'LiSi3Pd', 'Lu3SnC', 'MgPS3', ' ...
# S has 424 repetitions
#
#
#
# Br: ['Ag3SBr', 'AlBr3N', 'AlSBr3', 'BrNO3', 'CBr3F', 'CaInBr3', 'CdInBr3', 'CrInBr3', 'CsAuBr3', 'CsBrO3', 'CsCaBr3', 'CsCdBr3', 'CsCrBr3', 'CsCuBr3', 'CsDyBr3', 'CsEuBr3', 'CsFeBr3', 'CsGeBr3', 'CsHgBr3', 'CsMgBr3', 'CsMnBr3', 'CsNiBr3', 'CsPbBr3', 'CsSnBr3', 'CsTiBr3', 'CsVBr3', 'CuSe3Br', 'H3CBr', 'HgBrO3', 'InFeBr3', 'K3BrO', 'KBrO3', 'KFeBr3', 'KInBr3', 'KMnBr3', 'KTiBr3', 'TlBrO3', 'TlCdBr3', 'TlFeBr3', 'PBr3O', 'PaBr3O', 'Rb3BrO', 'RbAuBr3', 'RbBrO3', 'RbCdBr3', 'RbGeBr3', 'RbMnBr3', 'RbNiBr3', 'RbTiBr3', 'RbVBr3', 'Li3BrO', 'LiBrO3', 'LiGaBr3', 'MgInBr3', 'MnInBr3', 'NaBrO3', 'NbBr3O', 'NbSeBr3', 'NbTeBr3']
# Br has 59 repetitions
#
#
#
# I: ['Ag3SI', 'AgIO3', 'AgSe3I', 'AgTe3I', 'BaGe3Ir', 'BaIrO3', 'C3IN', 'CIF3', 'CaInBr3', 'CaIrO3', 'CaSi3Ir', 'CdInBr3', 'Ce3InC', 'CeGe3Ir', 'CeSi3Ir', 'Cr3IrN', 'CrInBr3', 'CrInO3', 'CsAuI3', 'CsCrI3', 'CsDyI3', 'CsGeI3', 'CsIO3', 'CsMgI3', 'CsMnI3', 'CsPbI3', 'CsSnI3', 'CsTiI3', 'CsVI3', 'CuSe3I', 'Dy3InC', 'Dy3InN', 'DySi3Ir', 'Er3InC', 'Er3InN', 'Eu3InO', 'EuGe3Ir', 'EuSi3Ir', 'Gd3InC', 'Gd3InN', 'GdSi3Ir', 'H3CI', 'HIO3', 'Ho3InC', 'Ho3InN', 'HoSi3Ir', 'IOF3', 'InBO3', 'InBiO3', 'InCo3N', 'InFeBr3', 'InFeO3', 'InGaO3', 'InGaS3', 'InNi3N', 'InPt3C', 'InRhO3', 'InSbS3', 'InSiTe3', 'K3IO', 'KAuI3', 'KHgI3', 'KIO3', 'KInBr3', 'KIrO3', 'KTiI3', 'KTmI3', 'La3InB', 'La3InC', 'La3InN', 'TlCdI3', 'TlFeI3', 'TlGeI3', 'TlIO3', 'TlPbI3', 'Tm3InC', 'Tm3InN', 'USi3Ir', 'WI3O', 'Y3InC', 'YInO3', 'YSi3Ir', 'NdSi3Ir', 'Pr3InC', 'Pr3InN', 'Pr3InO', 'PrInO3', 'Rb3IO', 'RbAuI3', 'RbCrI3', 'RbGeI3', 'RbIO3', 'RbPbI3', 'RbSnI3', 'RbTiI3', 'RbVI3', 'Sc3InB', 'Sc3InC', 'Sc3InN', 'ScBIr3', 'ScIr3C', 'SiH3I', 'Sm3InC', 'Sm3InN', 'SmSi3Ir', 'SrGe3Ir', 'SrIrO3', 'SrMgIn3', 'Tb3InC', 'Tb3InN', 'TbSi3Ir', 'ThSi3Ir', 'Ti3InC', 'Ti3InN', 'LaGe3Ir', 'LaIO3', 'LaInO3', 'LaSi3Ir', 'LiGaI3', 'LiIO3', 'LiScI3', 'Lu3InN', 'MgInBr3', 'Mn3GeIr', 'Mn3InC', 'Mn3IrN', 'Mn3SiIr', 'MnInBr3', 'MnInO3', 'MnTlI3', 'NaIO3', 'NaIrO3', 'NbI3O', 'NbSeI3', 'NbTeI3', 'Nd3InC', 'Nd3InN']
# I has 137 repetitions
#
#
#
# As: ['AgAsO3', 'AsCF3', 'AsCl3O', 'Ca3AsN', 'CeAsO3', 'CeSiAs3', 'Cr3AsC', 'Cr3AsN', 'KAsO3', 'V3AsC', 'V3AsN', 'PrSiAs3', 'SbAsO3', 'LaAsO3', 'LaSiAs3', 'LiAsO3', 'NaAsO3']
# As has 17 repetitions
#
#
#
# O: ['AgAsO3', 'AgBiO3', 'AgClO3', 'AgIO3', 'AgNO3', 'AgPO3', 'AgSbO3', 'AgTeO3', 'AlBO3', 'AlBiO3', 'AlFeO3', 'AsCl3O', 'Ba3GeO', 'Ba3PbO', 'Ba3SnO', 'BaBiO3', 'BaCO3', 'BaCeO3', 'BaClO3', 'BaCoO3', 'BaCrO3', 'BaFeO3', 'BaGeO3', 'BaIrO3', 'BaMnO3', 'BaMoO3', 'BaNbO3', 'BaNiO3', 'BaNpO3', 'BaOsO3', 'BaPaO3', 'BaPbO3', 'BaPrO3', 'BaPuO3', 'BaRhO3', 'BaRuO3', 'BaSeO3', 'BaSiO3', 'BaSnO3', 'BaTbO3', 'BaTcO3', 'BaTeO3', 'BaThO3', 'BaTiO3', 'BaVO3', 'BaZrO3', 'BiBO3', 'BiRhO3', 'BrNO3', 'Ca3GeO', 'Ca3PbO', 'Ca3SiO', 'Ca3SnO', 'CaBO3', 'CaCO3', 'CaCrO3', 'CaFeO3', 'CaGeO3', 'CaIrO3', 'CaMnO3', 'CaMoO3', 'CaNbO3', 'CaPbO3', 'CaPtO3', 'CaRhO3', 'CaRuO3', 'CaSeO3', 'CaSiO3', 'CaSnO3', 'CaTcO3', 'CaTeO3', 'CaTiO3', 'CaVO3', 'CaZrO3', 'CdCO3', 'CdGeO3', 'CdSO3', 'CdSeO3', 'CdSiO3', 'CdSnO3', 'CdTcO3', 'CdTeO3', 'CeAlO3', 'CeAsO3', 'CeBO3', 'CeCrO3', 'CeGaO3', 'CeScO3', 'CeSi3Os', 'CeVO3', 'CoBiO3', 'CoCO3', 'CoGeO3', 'CoSeO3', 'CoSiO3', 'CoTeO3', 'CrBO3', 'CrBiO3', 'CrCl3O', 'CrFeO3', 'CrInO3', 'CrOF3', 'CrPbO3', 'Cs3AuO', 'Cs3ClO', 'CsBrO3', 'CsIO3', 'CsNO3', 'CsNbO3', 'CsSO3', 'CsVO3', 'CuCO3', 'CuGeO3', 'CuSeO3', 'CuSiO3', 'CuTeO3', 'DyAlO3', 'DyBO3', 'DyCoO3', 'DyCrO3', 'DyFeO3', 'DyGaO3', 'DyMnO3', 'DyNiO3', 'DyScO3', 'DyVO3', 'ErBO3', 'ErCoO3', 'ErCrO3', 'ErFeO3', 'ErMnO3', 'ErNiO3', 'ErVO3', 'Eu3InO', 'EuAlO3', 'EuBO3', 'EuCO3', 'EuCrO3', 'EuFeO3', 'EuMnO3', 'EuNbO3', 'EuNiO3', 'EuRhO3', 'EuScO3', 'EuTiO3', 'EuZrO3', 'FeBO3', 'FeBiO3', 'FeCO3', 'FeGeO3', 'FeSO3', 'FeSiO3', 'GaBO3', 'GaBiO3', 'GaFeO3', 'GdAlO3', 'GdBO3', 'GdCrO3', 'GdFeO3', 'GdGaO3', 'GdMnO3', 'GdNiO3', 'GdScO3', 'GdTiO3', 'GdVO3', 'GePbO3', 'H3OF', 'HIO3', 'HNO3', 'HfPbO3', 'Hg3ClO', 'HgBrO3', 'HgClO3', 'HgNO3', 'HgSeO3', 'HgTeO3', 'HoAlO3', 'HoCoO3', 'HoCrO3', 'HoFeO3', 'HoGaO3', 'HoMnO3', 'HoNiO3', 'HoScO3', 'HoVO3', 'IOF3', 'InBO3', 'InBiO3', 'InFeO3', 'InGaO3', 'InRhO3', 'K3AuO', 'K3BrO', 'K3CO', 'K3ClO', 'K3IO', 'KAsO3', 'KBiO3', 'KBrO3', 'KCO3', 'KClO3', 'KIO3', 'KIrO3', 'KNO3', 'KNbO3', 'KPO3', 'KSO3', 'KSbO3', 'KSiO3', 'KTaO3', 'KTiO3', 'KUO3', 'KVO3', 'TiBO3', 'TiCdO3', 'TiCoO3', 'TiFeO3', 'TiHgO3', 'TiMnO3', 'TiNiO3', 'TiPbO3', 'TiZnO3', 'TlBrO3', 'TlClO3', 'TlCrO3', 'TlFeO3', 'TlIO3', 'TlNO3', 'TlNiO3', 'TlPO3', 'TlSbO3', 'TlVO3', 'TmBO3', 'TmCoO3', 'TmCrO3', 'TmFeO3', 'TmMnO3', 'TmNiO3', 'TmVO3', 'VAgO3', 'VBO3', 'VCdO3', 'VCl3O', 'VCuO3', 'VHgO3', 'VNO3', 'VPbO3', 'WCl3O', 'WI3O', 'YAlO3', 'YBO3', 'YCoO3', 'YCrO3', 'YFeO3', 'YGaO3', 'YInO3', 'YMnO3', 'YNiO3', 'YScO3', 'YTiO3', 'YVO3', 'ZnCO3', 'ZnGeO3', 'ZnPbO3', 'ZnSeO3', 'ZnSiO3', 'ZnSnO3', 'ZnTeO3', 'Zr3NiO', 'ZrPbO3', 'NdRhO3', 'NdScO3', 'NdSi3Os', 'NdTiO3', 'NdVO3', 'NiBiO3', 'NiCO3', 'NiSeO3', 'OsPbO3', 'PBr3O', 'PNO3', 'PPbO3', 'PaBr3O', 'PbCO3', 'PbSO3', 'PbSeO3', 'PdSeO3', 'Pr3InO', 'PrAlO3', 'PrBO3', 'PrCoO3', 'PrCrO3', 'PrFeO3', 'PrGaO3', 'PrInO3', 'PrLuO3', 'PrMnO3', 'PrNiO3', 'PrRhO3', 'PrRuO3', 'PrScO3', 'PrVO3', 'Rb3AuO', 'Rb3BrO', 'Rb3IO', 'RbBrO3', 'RbCO3', 'RbClO3', 'RbIO3', 'RbNO3', 'RbNbO3', 'RbPO3', 'RbSO3', 'RbSeO3', 'RbTaO3', 'RbUO3', 'RbVO3', 'ReClO3', 'ReO3F', 'SNO3', 'SbAsO3', 'ScAlO3', 'ScBO3', 'ScBiO3', 'ScCrO3', 'ScMnO3', 'ScRhO3', 'SiPbO3', 'SmAlO3', 'SmBO3', 'SmCoO3', 'SmCrO3', 'SmFeO3', 'SmMnO3', 'SmNiO3', 'SmRhO3', 'SmScO3', 'SmSi3Os', 'SmTiO3', 'SmVO3', 'SnHgO3', 'SnPO3', 'SnPbO3', 'Sr3GeO', 'Sr3PbO', 'Sr3SiO', 'Sr3SnO', 'SrBO3', 'SrBiO3', 'SrCO3', 'SrCeO3', 'SrCoO3', 'SrCrO3', 'SrFeO3', 'SrGeO3', 'SrHfO3', 'SrIrO3', 'SrMnO3', 'SrMoO3', 'SrNbO3', 'SrOsO3', 'SrPbO3', 'SrPrO3', 'SrRuO3', 'SrSeO3', 'SrSiO3', 'SrSnO3', 'SrTbO3', 'SrTcO3', 'SrTeO3', 'SrTiO3', 'SrVO3', 'SrZrO3', 'TaAgO3', 'TaSnO3', 'TbAlO3', 'TbCoO3', 'TbCrO3', 'TbFeO3', 'TbGa3Os', 'TbMnO3', 'TbRhO3', 'TbScO3', 'TbVO3', 'TcO3F', 'TcPbO3', 'TeHO3', 'TePbO3', 'ThSi3Os', 'LaAlO3', 'LaAsO3', 'LaAuO3', 'LaBO3', 'LaCoO3', 'LaCrO3', 'LaCuO3', 'LaErO3', 'LaFeO3', 'LaGaO3', 'LaGe3Os', 'LaHoO3', 'LaIO3', 'LaInO3', 'LaLuO3', 'LaMnO3', 'LaNiO3', 'LaPdO3', 'LaRhO3', 'LaRuO3', 'LaScO3', 'LaSi3Os', 'LaTiO3', 'LaTlO3', 'LaT ...
# O has 492 repetitions
#
#
#
# Bi: ['AgBiO3', 'AlBiO3', 'Ba3BiN', 'BaBiO3', 'BaBiSe3', 'BiBO3', 'BiPtPb3', 'BiRhO3', 'Ca3BiN', 'CoBiO3', 'CrBiO3', 'FeBiO3', 'GaBiO3', 'InBiO3', 'KBiO3', 'NiBiO3', 'ScBiO3', 'Sr3BiN', 'SrBiO3', 'SrBiSe3', 'LiBiO3', 'MnBiO3', 'NaBiO3']
# Bi has 23 repetitions
#
#
#
# Cl: ['AgClO3', 'AsCl3O', 'AuNCl3', 'BaClO3', 'BaN3Cl', 'CCl3F', 'CClF3', 'CN3Cl', 'CaNCl3', 'CdNCl3', 'CrCl3O', 'Cs3ClO', 'CsAgCl3', 'CsAuCl3', 'CsCdCl3', 'CsCoCl3', 'CsCrCl3', 'CsCuCl3', 'CsEuCl3', 'CsFeCl3', 'CsGeCl3', 'CsHgCl3', 'CsMgCl3', 'CsMnCl3', 'CsNiCl3', 'CsPbCl3', 'CsPdCl3', 'CsScCl3', 'CsSmCl3', 'CsSnCl3', 'CsTiCl3', 'CsTmCl3', 'CsVCl3', 'CuNCl3', 'FeNCl3', 'GeH3Cl', 'GeNCl3', 'H3CCl', 'H3NCl', 'Hg3ClO', 'HgClO3', 'HgNCl3', 'K3ClO', 'KCdCl3', 'KClO3', 'KCuCl3', 'KFeCl3', 'KMgCl3', 'KMnCl3', 'KNiCl3', 'KTcCl3', 'KTiCl3', 'TlCdCl3', 'TlClO3', 'TlCoCl3', 'TlCuCl3', 'TlHgCl3', 'VCl3O', 'WCl3O', 'RbCdCl3', 'RbClO3', 'RbCoCl3', 'RbCrCl3', 'RbCuCl3', 'RbGeCl3', 'RbMgCl3', 'RbMnCl3', 'RbNiCl3', 'RbTiCl3', 'RbVCl3', 'ReClO3', 'SnCCl3', 'LiGaCl3', 'MnClO3', 'MnNCl3', 'MnTlCl3', 'MoCl3O', 'MoNCl3', 'NClO3', 'Na3ClO', 'NaClO3', 'NaHgCl3', 'NaMnCl3', 'NbCl3O', 'NbSeCl3']
# Cl has 85 repetitions
#
#
#
# N: ['AgNO3', 'AlBr3N', 'AuNCl3', 'Ba3BiN', 'Ba3LiN', 'Ba3NaN', 'Ba3SbN', 'BaN3Cl', 'BaNbO3', 'BaNiO3', 'BaNiSn3', 'BaNpO3', 'BeNF3', 'BrNO3', 'C3IN', 'CN3Cl', 'CS3N', 'Ca3AsN', 'Ca3AuN', 'Ca3BiN', 'Ca3GeN', 'Ca3PN', 'Ca3PbN', 'Ca3SbN', 'Ca3SnN', 'Ca3TlN', 'CaNCl3', 'CaNbO3', 'CaNiH3', 'CdCo3N', 'CdNCl3', 'CdNF3', 'CdNi3N', 'Ce3AlN', 'CeNiSb3', 'Cr3AsN', 'Cr3GaN', 'Cr3GeN', 'Cr3IrN', 'Cr3PN', 'Cr3PdN', 'Cr3PtN', 'Cr3RhN', 'Cr3SnN', 'CsNO3', 'CsNbO3', 'CsNiBr3', 'CsNiCl3', 'CsNiF3', 'CuNCl3', 'Dy3InN', 'DyNiGe3', 'DyNiO3', 'Er3InN', 'ErNiGe3', 'ErNiO3', 'ErSi3Ni', 'EuNbO3', 'EuNiGe3', 'EuNiO3', 'Fe3NiN', 'Fe3PdN', 'Fe3PtN', 'Fe3RhN', 'FeNCl3', 'Gd3InN', 'GdNiGe3', 'GdNiO3', 'GeNCl3', 'H3NCl', 'HNO3', 'HS3N', 'Hf3AlN', 'HgNCl3', 'HgNO3', 'HgSN3', 'Ho3GaNi', 'Ho3InN', 'HoNiGe3', 'HoNiO3', 'InCo3N', 'InNi3N', 'KNO3', 'KNbO3', 'KNiCl3', 'KNiF3', 'KSnN3', 'La3AlN', 'La3InN', 'Ti3TlN', 'TiNiO3', 'TlNO3', 'TlNiO3', 'Tm3InN', 'TmNiGe3', 'TmNiO3', 'UGa3Ni', 'UNiS3', 'UNiSe3', 'V3AsN', 'V3AuN', 'V3GaN', 'V3GeN', 'V3PN', 'VNO3', 'YAl3Ni', 'YNiGe3', 'YNiO3', 'YSi3Ni', 'ZnNi3C', 'Zr3AlN', 'Zr3NiO', 'ZrNiH3', 'NdRh3C', 'NdRhO3', 'NdScO3', 'NdSi3Ir', 'NdSi3Os', 'NdSi3Rh', 'NdSi3Ru', 'NdSn3Ru', 'NdTiO3', 'NdTmS3', 'NdVGe3', 'NdVO3', 'Ni3GeC', 'NiBiO3', 'NiCO3', 'NiNF3', 'NiPS3', 'NiPSe3', 'NiSeO3', 'PNO3', 'Pr3AlN', 'Pr3InN', 'PrNiGe3', 'PrNiO3', 'PrNiSb3', 'RbNO3', 'RbNbO3', 'RbNiBr3', 'RbNiCl3', 'RbNiF3', 'SNO3', 'Sc3InN', 'ScSi3Ni', 'Sm3AlN', 'Sm3InN', 'SmNiGe3', 'SmNiO3', 'SmNiSb3', 'SmSi3Ni', 'SnNF3', 'Sr3BiN', 'Sr3SbN', 'SrNbO3', 'SrNiSn3', 'SrSi3Ni', 'Tb3InN', 'TbNiGe3', 'ThTaN3', 'Ti3AlN', 'Ti3InN', 'LaNi3B', 'LaNiO3', 'LaNiSb3', 'LiNO3', 'LiNbO3', 'Lu3InN', 'LuNiGe3', 'LuNiO3', 'MgNi3C', 'Mn3AgN', 'Mn3CuN', 'Mn3GaN', 'Mn3IrN', 'Mn3NiN', 'Mn3PdN', 'Mn3PtN', 'Mn3RhN', 'Mn3SnN', 'Mn3ZnN', 'MnNCl3', 'MnNF3', 'MnNiO3', 'MoNCl3', 'NClO3', 'Na3ClO', 'NaAsO3', 'NaBPt3', 'NaBiO3', 'NaBrO3', 'NaCO3', 'NaClO3', 'NaCoF3', 'NaCuF3', 'NaFeF3', 'NaGeAu3', 'NaHgCl3', 'NaIO3', 'NaIrO3', 'NaMgF3', 'NaMgH3', 'NaMnCl3', 'NaMnF3', 'NaNO3', 'NaNbO3', 'NaNiF3', 'NaOsO3', 'NaPO3', 'NaPS3', 'NaSbO3', 'NaSeO3', 'NaSiAu3', 'NaTaO3', 'NaUO3', 'NaVF3', 'NaVO3', 'NaWO3', 'NaZnF3', 'NaZnO3', 'NbAgO3', 'NbBr3O', 'NbCl3O', 'NbCuO3', 'NbI3O', 'NbRu3C', 'NbSeBr3', 'NbSeCl3', 'NbSeI3', 'NbTeBr3', 'NbTeI3', 'Nd3AlC', 'Nd3AlN', 'Nd3GaC', 'Nd3GaN', 'Nd3InC', 'Nd3InN', 'Nd3PbC', 'Nd3PbN', 'Nd3SnC', 'Nd3SnN', 'Nd3TlC', 'Nd3TlN', 'NdAl3Cu', 'NdAlO3', 'NdBO3', 'NdBPd3', 'NdBPt3', 'NdBRh3', 'NdBS3', 'NdCoGe3', 'NdCoO3', 'NdCoSb3', 'NdCoSi3', 'NdCrGe3', 'NdCrO3', 'NdCrS3', 'NdFeO3', 'NdFeSb3', 'NdGaO3', 'NdLuSe3', 'NdMnO3', 'NdNiGe3', 'NdNiO3', 'NdNiSb3']
# N has 266 repetitions
#
#
#
# P: ['AgPO3', 'AgPS3', 'AgPd3Se', 'AlPt3C', 'AlSiP3', 'Ba3PbO', 'BaGe3Pd', 'BaGe3Pt', 'BaPS3', 'BaPSe3', 'BaPaO3', 'BaPbO3', 'BaPrO3', 'BaPuO3', 'BaSi3Pd', 'BaSi3Pt', 'BaSn3Pd', 'BaSn3Pt', 'BiPtPb3', 'Ca3PN', 'Ca3PbN', 'Ca3PbO', 'CaPS3', 'CaPSe3', 'CaPbO3', 'CaPd3C', 'CaPtO3', 'CaSi3Pt', 'CdPS3', 'CdPSe3', 'Ce3PbC', 'CeBPd3', 'CeBPt3', 'CeGa3Pd', 'CeSb3Pd', 'CeSiP3', 'CoPS3', 'Cr3PC', 'Cr3PN', 'Cr3PdN', 'Cr3PtN', 'CrPSe3', 'CrPbO3', 'CsPS3', 'CsPbBr3', 'CsPbCl3', 'CsPbF3', 'CsPbI3', 'CsPdCl3', 'CuPS3', 'Dy3PbC', 'DyBPd3', 'Er3PbC', 'ErBPd3', 'EuBPd3', 'EuGa3Pd', 'EuGe3Pd', 'EuGe3Pt', 'EuH3Pd', 'EuPS3', 'EuPSe3', 'Fe3PdN', 'Fe3PtN', 'FePS3', 'FePSe3', 'GaPt3C', 'Gd3PbC', 'GdBPd3', 'GePbO3', 'GePbS3', 'GePdS3', 'HfPbO3', 'HfPbS3', 'HgPS3', 'HgPSe3', 'HoBPd3', 'InPt3C', 'KPO3', 'KPS3', 'KPSe3', 'KPdF3', 'La3PbC', 'TiPbO3', 'TlHPd3', 'TlPO3', 'TlPS3', 'TlPbI3', 'Tm3PbC', 'TmBPd3', 'UPdSe3', 'V3PC', 'V3PN', 'VPS3', 'VPbO3', 'Y3PbC', 'ZnPS3', 'ZnPbO3', 'ZrPbO3', 'ZrPbS3', 'NiPS3', 'NiPSe3', 'OsPbO3', 'PBr3O', 'PCF3', 'PNO3', 'PPbO3', 'PPbSe3', 'PaBr3O', 'PbCO3', 'PbSO3', 'PbSeO3', 'Pd3PbC', 'PdSeO3', 'Pr3AlC', 'Pr3AlN', 'Pr3GaC', 'Pr3InC', 'Pr3InN', 'Pr3InO', 'Pr3PbC', 'Pr3SnC', 'Pr3TlC', 'PrAl3Cu', 'PrAlO3', 'PrBO3', 'PrBPd3', 'PrBPt3', 'PrBRh3', 'PrBS3', 'PrCoGe3', 'PrCoO3', 'PrCoSb3', 'PrCrGe3', 'PrCrO3', 'PrErS3', 'PrFeGe3', 'PrFeO3', 'PrFeSb3', 'PrGaO3', 'PrGe3Rh', 'PrInO3', 'PrLuO3', 'PrLuSe3', 'PrMnO3', 'PrNiGe3', 'PrNiO3', 'PrNiSb3', 'PrRh3C', 'PrRhO3', 'PrRuO3', 'PrScO3', 'PrSiAs3', 'PrSiP3', 'PrSn3Ru', 'PrTmS3', 'PrVGe3', 'PrVO3', 'Pt3PbC', 'PuRh3C', 'PuRu3C', 'RbPO3', 'RbPS3', 'RbPSe3', 'RbPbF3', 'RbPbI3', 'RbPdF3', 'Sc3BPb', 'Sc3PbC', 'SiPbO3', 'Sm3PbC', 'SmBPd3', 'SnPO3', 'SnPS3', 'SnPSe3', 'SnPbO3', 'SnPbS3', 'SnPt3C', 'Sr3PbO', 'SrGa3Pd', 'SrGe3Pd', 'SrGe3Pt', 'SrPS3', 'SrPSe3', 'SrPbO3', 'SrPrO3', 'SrSn3Pd', 'Tb3PbC', 'TbBPd3', 'TcPbO3', 'TePbO3', 'LaBPd3', 'LaPdO3', 'LiBPt3', 'LiPO3', 'LiSi3Pd', 'LuBPd3', 'MgPS3', 'MgPSe3', 'Mn3PdN', 'Mn3PtN', 'MnPS3', 'MnPSe3', 'MnPbO3', 'NaBPt3', 'NaPO3', 'NaPS3', 'Nd3PbC', 'Nd3PbN', 'NdBPd3', 'NdBPt3']
# P has 210 repetitions
#
#
#
# Pd: ['AgPd3Se', 'BaGe3Pd', 'BaSi3Pd', 'BaSn3Pd', 'CaPd3C', 'CeBPd3', 'CeGa3Pd', 'CeSb3Pd', 'Cr3PdN', 'CsPdCl3', 'DyBPd3', 'ErBPd3', 'EuBPd3', 'EuGa3Pd', 'EuGe3Pd', 'EuH3Pd', 'Fe3PdN', 'GdBPd3', 'GePdS3', 'HoBPd3', 'KPdF3', 'TlHPd3', 'TmBPd3', 'UPdSe3', 'Pd3PbC', 'PdSeO3', 'PrBPd3', 'RbPdF3', 'SmBPd3', 'SrGa3Pd', 'SrGe3Pd', 'SrSn3Pd', 'TbBPd3', 'LaBPd3', 'LaPdO3', 'LiSi3Pd', 'LuBPd3', 'Mn3PdN', 'NdBPd3']
# Pd has 39 repetitions
#
#
#
# Se: ['AgPd3Se', 'AgSe3I', 'BaBiSe3', 'BaPSe3', 'BaSeO3', 'BaTaSe3', 'BaTiSe3', 'BaVSe3', 'BaZrSe3', 'CaPSe3', 'CaSeO3', 'CdPSe3', 'CdSeO3', 'CeCrSe3', 'CoSeO3', 'CrGaSe3', 'CrPSe3', 'CrSbSe3', 'CsAuSe3', 'CsBSe3', 'CsGaSe3', 'CsSnSe3', 'CsTeSe3', 'CuSe3Br', 'CuSe3I', 'CuSeO3', 'EuPSe3', 'EuZrSe3', 'FePSe3', 'H3CSe', 'HgPSe3', 'HgSeO3', 'KPSe3', 'TlBSe3', 'UCoSe3', 'UCrSe3', 'UFeSe3', 'UMnSe3', 'UNiSe3', 'UPdSe3', 'UVSe3', 'ZnSeO3', 'NiPSe3', 'NiSeO3', 'PPbSe3', 'PbSeO3', 'PdSeO3', 'PrLuSe3', 'RbBSe3', 'RbPSe3', 'RbSeO3', 'SnPSe3', 'SrBiSe3', 'SrPSe3', 'SrSbSe3', 'SrSeO3', 'SrZrSe3', 'TaTlSe3', 'ThCrSe3', 'ThMnSe3', 'LaCrSe3', 'MgPSe3', 'MgSeO3', 'MnPSe3', 'MnSeO3', 'NaSeO3', 'NbSeBr3', 'NbSeCl3', 'NbSeI3', 'NdLuSe3']
# Se has 70 repetitions
#
#
#
# Sb: ['AgSbO3', 'Ba3SbN', 'BaSbTe3', 'Ca3SbN', 'CeCoSb3', 'CeNiSb3', 'CeSb3Pd', 'CrSbS3', 'CrSbSe3', 'InSbS3', 'KSbO3', 'TlSbO3', 'PrCoSb3', 'PrFeSb3', 'PrNiSb3', 'SbAsO3', 'SmCoSb3', 'SmFeSb3', 'SmNiSb3', 'Sr3SbN', 'SrSbSe3', 'TbFeSb3', 'LaCoSb3', 'LaCrSb3', 'LaNiSb3', 'LiSbO3', 'NaSbO3', 'NdCoSb3', 'NdFeSb3', 'NdNiSb3']
# Sb has 30 repetitions
#
#
#
# Te: ['AgTe3I', 'AgTeO3', 'BaSbTe3', 'BaTeO3', 'BaTeS3', 'CaTeO3', 'CdTeO3', 'CoTeO3', 'CrGeTe3', 'CrSiTe3', 'CsAlTe3', 'CsSiTe3', 'CsTeSe3', 'CuTeO3', 'HgTeO3', 'InSiTe3', 'KTaTe3', 'ZnTeO3', 'SrTeO3', 'TaFeTe3', 'TeCF3', 'TeHO3', 'TePbO3', 'NbTeBr3', 'NbTeI3']
# Te has 25 repetitions
#
#
#
# Al: ['AlBO3', 'AlBiO3', 'AlBr3N', 'AlCo3C', 'AlFe3C', 'AlFeO3', 'AlPt3C', 'AlSBr3', 'AlSiP3', 'Ce3AlC', 'Ce3AlN', 'CeAl3Au', 'CeAl3Cu', 'CeAlO3', 'CsAlTe3', 'Dy3AlC', 'DyAlO3', 'Er3AlC', 'EuAlO3', 'Gd3AlC', 'GdAl3Cu', 'GdAlO3', 'Hf3AlN', 'Ho3AlC', 'HoAlO3', 'La3AlC', 'La3AlN', 'Tm3AlC', 'Y3AlC', 'YAl3Ni', 'YAlO3', 'Zr3AlN', 'Pr3AlC', 'Pr3AlN', 'PrAl3Cu', 'PrAlO3', 'Sc3AlC', 'ScAlO3', 'Sm3AlC', 'Sm3AlN', 'SmAlO3', 'SrAlH3', 'Tb3AlC', 'TbAlO3', 'Ti3AlC', 'Ti3AlN', 'LaAl3Au', 'LaAl3Cu', 'LaAlO3', 'LiCaAl3', 'Mn3AlC', 'Nd3AlC', 'Nd3AlN', 'NdAl3Cu', 'NdAlO3']
# Al has 55 repetitions
#
#
#
# B: ['Ag3SBr', 'AgBiO3', 'AlBO3', 'AlBiO3', 'AlBr3N', 'AlSBr3', 'Ba3BiN', 'Ba3GeO', 'Ba3LiN', 'Ba3NaN', 'Ba3PbO', 'Ba3SbN', 'Ba3SnO', 'BaBiO3', 'BaBiSe3', 'BaCO3', 'BaCaSn3', 'BaCeO3', 'BaClO3', 'BaCoO3', 'BaCrO3', 'BaFeO3', 'BaGe3Ir', 'BaGe3Pd', 'BaGe3Pt', 'BaGe3Rh', 'BaGeO3', 'BaGeS3', 'BaHfS3', 'BaIrO3', 'BaLiF3', 'BaLiH3', 'BaMnO3', 'BaMoO3', 'BaN3Cl', 'BaNbO3', 'BaNiO3', 'BaNiSn3', 'BaNpO3', 'BaOsO3', 'BaPS3', 'BaPSe3', 'BaPaO3', 'BaPbO3', 'BaPrO3', 'BaPuO3', 'BaRhO3', 'BaRuO3', 'BaSbTe3', 'BaSeO3', 'BaSi3Pd', 'BaSi3Pt', 'BaSiO3', 'BaSn3Au', 'BaSn3Pd', 'BaSn3Pt', 'BaSnO3', 'BaSnS3', 'BaTaS3', 'BaTaSe3', 'BaTbO3', 'BaTcO3', 'BaTeO3', 'BaTeS3', 'BaThO3', 'BaTiO3', 'BaTiS3', 'BaTiSe3', 'BaUS3', 'BaVO3', 'BaVS3', 'BaVSe3', 'BaZrO3', 'BaZrS3', 'BaZrSe3', 'BeNF3', 'BiBO3', 'BiPtPb3', 'BiRhO3', 'BrNO3', 'CBr3F', 'Ca3BiN', 'CaBO3', 'CaInBr3', 'CdInBr3', 'CeBO3', 'CeBPd3', 'CeBPt3', 'CeBRh3', 'CeBS3', 'CoBiO3', 'CrBO3', 'CrBiO3', 'CrInBr3', 'CsAuBr3', 'CsBSe3', 'CsBeF3', 'CsBrO3', 'CsCaBr3', 'CsCdBr3', 'CsCrBr3', 'CsCuBr3', 'CsDyBr3', 'CsEuBr3', 'CsFeBr3', 'CsGeBr3', 'CsHgBr3', 'CsMgBr3', 'CsMnBr3', 'CsNiBr3', 'CsPbBr3', 'CsSnBr3', 'CsTiBr3', 'CsVBr3', 'CuSe3Br', 'DyBO3', 'DyBPd3', 'DyBRh3', 'ErB3Mo', 'ErBO3', 'ErBPd3', 'ErBRh3', 'EuBO3', 'EuBPd3', 'EuBRh3', 'FeBO3', 'FeBiO3', 'GaBO3', 'GaBiO3', 'GdBO3', 'GdBPd3', 'GdBRh3', 'H3CBr', 'HfBRh3', 'HgBrO3', 'HoBPd3', 'HoBRh3', 'InBO3', 'InBiO3', 'InFeBr3', 'K3BrO', 'KBiO3', 'KBrO3', 'KFeBr3', 'KInBr3', 'KMnBr3', 'KTiBr3', 'La3InB', 'TiBO3', 'TlBS3', 'TlBSe3', 'TlBrO3', 'TlCdBr3', 'TlFeBr3', 'TmBO3', 'TmBPd3', 'TmBRh3', 'UBRh3', 'UReB3', 'VBO3', 'VCoB3', 'YBO3', 'YBRh3', 'ZrBRh3', 'NiBiO3', 'PBr3O', 'PaBr3O', 'PrBO3', 'PrBPd3', 'PrBPt3', 'PrBRh3', 'PrBS3', 'Rb3BrO', 'RbAuBr3', 'RbBS3', 'RbBSe3', 'RbBrO3', 'RbCdBr3', 'RbGeBr3', 'RbMnBr3', 'RbNiBr3', 'RbTiBr3', 'RbVBr3', 'Sc3BPb', 'Sc3InB', 'Sc3SnB', 'Sc3TlB', 'ScBIr3', 'ScBO3', 'ScBRh3', 'ScBiO3', 'SmBO3', 'SmBPd3', 'SmBRh3', 'SmBS3', 'Sr3BiN', 'SrBO3', 'SrBiO3', 'SrBiSe3', 'TbBPd3', 'TbBRh3', 'TbBS3', 'LaBO3', 'LaBPd3', 'LaBRh3', 'LaNi3B', 'Li3BrO', 'LiBPt3', 'LiBiO3', 'LiBrO3', 'LiGaBr3', 'LuBO3', 'LuBPd3', 'LuBRh3', 'MgBO3', 'MgInBr3', 'MnBiO3', 'MnInBr3', 'NaBPt3', 'NaBiO3', 'NaBrO3', 'NbBr3O', 'NbSeBr3', 'NbTeBr3', 'NdBO3', 'NdBPd3', 'NdBPt3', 'NdBRh3', 'NdBS3']
# B has 229 repetitions
#
#
#
# Co: ['AlCo3C', 'BaCoO3', 'CdCo3N', 'CeCoGe3', 'CeCoSb3', 'Co3SnC', 'CoBiO3', 'CoCO3', 'CoGeO3', 'CoPS3', 'CoSeO3', 'CoSiO3', 'CoTeO3', 'CsCoCl3', 'CsCoF3', 'DyCoO3', 'ErCoO3', 'EuCoGe3', 'GdCoSi3', 'HoCoO3', 'InCo3N', 'KCoF3', 'TiCoO3', 'TlCoCl3', 'TmCoO3', 'UCoSe3', 'VCoB3', 'YCoO3', 'ZnCo3C', 'ZrCoH3', 'PrCoGe3', 'PrCoO3', 'PrCoSb3', 'RbCoCl3', 'RbCoF3', 'ScCo3C', 'SmCoO3', 'SmCoSb3', 'SmCoSi3', 'SrCoO3', 'TbCoO3', 'TbCoSi3', 'ThCoSi3', 'LaCoGe3', 'LaCoO3', 'LaCoSb3', 'LaCoSi3', 'LuCoO3', 'MgCo3C', 'MnCoO3', 'NaCoF3', 'NdCoGe3', 'NdCoO3', 'NdCoSb3', 'NdCoSi3']
# Co has 55 repetitions
#
#
#
# C: ['AgClO3', 'AlCo3C', 'AlFe3C', 'AlPt3C', 'AsCF3', 'AsCl3O', 'AuNCl3', 'BaCO3', 'BaCaSn3', 'BaCeO3', 'BaClO3', 'BaCoO3', 'BaCrO3', 'BaN3Cl', 'C3IN', 'CBr3F', 'CCl3F', 'CClF3', 'CIF3', 'CN3Cl', 'CS3N', 'Ca3AsN', 'Ca3AuN', 'Ca3BiN', 'Ca3GeN', 'Ca3GeO', 'Ca3PN', 'Ca3PbN', 'Ca3PbO', 'Ca3SbN', 'Ca3SiO', 'Ca3SnN', 'Ca3SnO', 'Ca3TlN', 'CaBO3', 'CaCO3', 'CaCrO3', 'CaFeO3', 'CaGaAu3', 'CaGeO3', 'CaHfS3', 'CaInBr3', 'CaIrO3', 'CaMnO3', 'CaMoO3', 'CaNCl3', 'CaNbO3', 'CaNiH3', 'CaPS3', 'CaPSe3', 'CaPbO3', 'CaPd3C', 'CaPtO3', 'CaRhO3', 'CaRuO3', 'CaSeO3', 'CaSi3Ir', 'CaSi3Pt', 'CaSiO3', 'CaSnO3', 'CaTcO3', 'CaTeO3', 'CaTiO3', 'CaVO3', 'CaZrO3', 'CaZrS3', 'CdCO3', 'CdCo3N', 'CdGeO3', 'CdInBr3', 'CdNCl3', 'CdNF3', 'CdNi3N', 'CdPS3', 'CdPSe3', 'CdSO3', 'CdSeO3', 'CdSiO3', 'CdSnO3', 'CdTcO3', 'CdTeO3', 'Ce3AlC', 'Ce3AlN', 'Ce3InC', 'Ce3PbC', 'Ce3SnC', 'Ce3TlC', 'CeAl3Au', 'CeAl3Cu', 'CeAlO3', 'CeAsO3', 'CeBO3', 'CeBPd3', 'CeBPt3', 'CeBRh3', 'CeBS3', 'CeCoGe3', 'CeCoSb3', 'CeCrGe3', 'CeCrO3', 'CeCrS3', 'CeCrSe3', 'CeDyS3', 'CeErS3', 'CeFeGe3', 'CeGa3Pd', 'CeGaO3', 'CeGe3Ir', 'CeGe3Rh', 'CeGe3Ru', 'CeLuS3', 'CeNiSb3', 'CeRh3C', 'CeSb3Pd', 'CeScO3', 'CeScS3', 'CeSi3Ir', 'CeSi3Os', 'CeSi3Rh', 'CeSi3Ru', 'CeSiAs3', 'CeSiP3', 'CeSn3Ru', 'CeTmS3', 'CeVO3', 'Co3SnC', 'CoBiO3', 'CoCO3', 'CoGeO3', 'CoPS3', 'CoSeO3', 'CoSiO3', 'CoTeO3', 'Cr3AsC', 'Cr3AsN', 'Cr3GaN', 'Cr3GeC', 'Cr3GeN', 'Cr3IrN', 'Cr3PC', 'Cr3PN', 'Cr3PdN', 'Cr3PtN', 'Cr3RhN', 'Cr3SnN', 'CrBO3', 'CrBiO3', 'CrCl3O', 'CrFeO3', 'CrGaSe3', 'CrGeTe3', 'CrInBr3', 'CrInO3', 'CrOF3', 'CrPSe3', 'CrPbO3', 'CrSbS3', 'CrSbSe3', 'CrSiTe3', 'Cs3AuO', 'Cs3ClO', 'CsAgCl3', 'CsAgF3', 'CsAlTe3', 'CsAuBr3', 'CsAuCl3', 'CsAuI3', 'CsAuSe3', 'CsBSe3', 'CsBeF3', 'CsBrO3', 'CsCaBr3', 'CsCaF3', 'CsCaH3', 'CsCdBr3', 'CsCdCl3', 'CsCdF3', 'CsCoCl3', 'CsCoF3', 'CsCrBr3', 'CsCrCl3', 'CsCrI3', 'CsCuBr3', 'CsCuCl3', 'CsDyBr3', 'CsDyI3', 'CsEuBr3', 'CsEuCl3', 'CsEuF3', 'CsFeBr3', 'CsFeCl3', 'CsFeF3', 'CsGaS3', 'CsGaSe3', 'CsGeBr3', 'CsGeCl3', 'CsGeI3', 'CsHgBr3', 'CsHgCl3', 'CsHgF3', 'CsIO3', 'CsMgBr3', 'CsMgCl3', 'CsMgF3', 'CsMgH3', 'CsMgI3', 'CsMnBr3', 'CsMnCl3', 'CsMnF3', 'CsMnI3', 'CsNO3', 'CsNbO3', 'CsNiBr3', 'CsNiCl3', 'CsNiF3', 'CsPS3', 'CsPbBr3', 'CsPbCl3', 'CsPbF3', 'CsPbI3', 'CsPdCl3', 'CsSO3', 'CsScCl3', 'CsSiTe3', 'CsSmCl3', 'CsSnBr3', 'CsSnCl3', 'CsSnF3', 'CsSnI3', 'CsSnS3', 'CsSnSe3', 'CsSrF3', 'CsTeSe3', 'CsTiBr3', 'CsTiCl3', 'CsTiI3', 'CsTlF3', 'CsTmCl3', 'CsVBr3', 'CsVCl3', 'CsVI3', 'CsVO3', 'Cu3SnAu', 'CuAgF3', 'CuCO3', 'CuGeO3', 'CuNCl3', 'CuPS3', 'CuSe3Br', 'CuSe3I', 'CuSeO3', 'CuSiO3', 'CuTeO3', 'Dy3AlC', 'Dy3GaC', 'Dy3InC', 'Dy3PbC', 'Dy3SnC', 'Dy3TlC', 'DyCoO3', 'DyCrO3', 'DyRh3C', 'Er3AlC', 'Er3GaC', 'Er3InC', 'Er3PbC', 'Er3SnC', 'Er3TlC', 'ErCoO3', 'ErCrO3', 'ErRh3C', 'EuCO3', 'EuCoGe3', 'EuCrO3', 'EuRh3C', 'Fe3SnC', 'FeCO3', 'FeNCl3', 'GaPt3C', 'Gd3AlC', 'Gd3InC', 'Gd3PbC', 'GdAl3Cu', 'GdCoSi3', 'GdCrO3', 'GdRh3C', 'GeH3Cl', 'GeNCl3', 'H3CBr', 'H3CCl', 'H3CI', 'H3CS', 'H3CSe', 'H3NCl', 'Hg3ClO', 'HgClO3', 'HgNCl3', 'Ho3AlC', 'Ho3GaC', 'Ho3InC', 'Ho3SnC', 'Ho3TlC', 'HoCoO3', 'HoCrO3', 'HoRh3C', 'InCo3N', 'InPt3C', 'K3CO', 'K3ClO', 'KCO3', 'KCaF3', 'KCdCl3', 'KCdF3', 'KClO3', 'KCoF3', 'KCrF3', 'KCuCl3', 'KCuF3', 'KFeCl3', 'KMgCl3', 'KMnCl3', 'KNiCl3', 'KTcCl3', 'KTiCl3', 'La3AlC', 'La3InC', 'La3PbC', 'La3TlC', 'TiCdO3', 'TiCoO3', 'TlCdBr3', 'TlCdCl3', 'TlCdI3', 'TlClO3', 'TlCoCl3', 'TlCrO3', 'TlCuCl3', 'TlHgCl3', 'Tm3AlC', 'Tm3GaC', 'Tm3InC', 'Tm3PbC', 'Tm3SnC', 'Tm3TlC', 'TmCoO3', 'TmCrO3', 'TmRh3C', 'UCoSe3', 'UCrS3', 'UCrSe3', 'V3AsC', 'V3GeC', 'V3PC', 'VCdO3', 'VCl3O', 'VCoB3', 'VCuO3', 'VRu3C', 'WCl3O', 'Y3AlC', 'Y3GaC', 'Y3InC', 'Y3PbC', 'Y3SnC', 'Y3TlC', 'YCoO3', 'YCrO3', 'YRh3C', 'ZnCO3', 'ZnCo3C', 'ZnFe3C', 'ZnNi3C', 'ZrCoH3', 'ZrRu3C', 'NdRh3C', 'Ni3GeC', 'NiCO3', 'PCF3', 'PbCO3', 'Pd3PbC', 'Pr3AlC', 'Pr3GaC', 'Pr3InC', 'Pr3PbC', 'Pr3SnC', 'Pr3TlC', 'PrAl3Cu', 'PrCoGe3', 'PrCoO3', 'PrCoSb3', 'PrCrGe3', 'PrCrO3', 'PrRh3C', 'Pt3PbC', 'PuRh3C', 'PuRu3C', 'RbCO3', 'RbCaF3', 'RbCaH3', 'RbCd ...
# C has 527 repetitions
#
#
#
# Fe: ['AlFe3C', 'AlFeO3', 'BaFeO3', 'CaFeO3', 'CeFeGe3', 'CrFeO3', 'CsFeBr3', 'CsFeCl3', 'CsFeF3', 'DyFeO3', 'ErFeO3', 'EuFeO3', 'Fe3NiN', 'Fe3PdN', 'Fe3PtN', 'Fe3RhN', 'Fe3SnC', 'FeBO3', 'FeBiO3', 'FeCO3', 'FeGeO3', 'FeNCl3', 'FePS3', 'FePSe3', 'FeSO3', 'FeSiO3', 'GaFeO3', 'GdFeO3', 'HoFeO3', 'InFeBr3', 'InFeO3', 'KFeBr3', 'KFeCl3', 'KFeF3', 'TiFeO3', 'TlFeBr3', 'TlFeI3', 'TlFeO3', 'TmFeO3', 'UFeS3', 'UFeSe3', 'YFeO3', 'ZnFe3C', 'PrFeGe3', 'PrFeO3', 'PrFeSb3', 'RbFeF3', 'SmFeO3', 'SmFeSb3', 'SrFeO3', 'TaFeTe3', 'TbFeO3', 'TbFeSb3', 'LaFeGe3', 'LaFeO3', 'LuFeO3', 'NaFeF3', 'NdFeO3', 'NdFeSb3']
# Fe has 59 repetitions
#
#
#
# Pt: ['AlPt3C', 'BaGe3Pt', 'BaSi3Pt', 'BaSn3Pt', 'BiPtPb3', 'CaPtO3', 'CaSi3Pt', 'CeBPt3', 'Cr3PtN', 'EuGe3Pt', 'Fe3PtN', 'GaPt3C', 'InPt3C', 'PrBPt3', 'Pt3PbC', 'SnPt3C', 'SrGe3Pt', 'LiBPt3', 'Mn3PtN', 'NaBPt3', 'NdBPt3']
# Pt has 21 repetitions
#
#
#
# Si: ['AlSiP3', 'BaSi3Pd', 'BaSi3Pt', 'BaSiO3', 'Ca3SiO', 'CaSi3Ir', 'CaSi3Pt', 'CaSiO3', 'CdSiO3', 'CeSi3Ir', 'CeSi3Os', 'CeSi3Rh', 'CeSi3Ru', 'CeSiAs3', 'CeSiP3', 'CoSiO3', 'CrSiTe3', 'CsSiTe3', 'CuSiO3', 'DySi3Ir', 'ErSi3Ni', 'EuSi3Ir', 'EuSi3Rh', 'FeSiO3', 'GdCoSi3', 'GdSi3Ir', 'HoSi3Ir', 'InSiTe3', 'KSiH3', 'KSiO3', 'USi3Ir', 'YSi3Ir', 'YSi3Ni', 'ZnSiO3', 'NdSi3Ir', 'NdSi3Os', 'NdSi3Rh', 'NdSi3Ru', 'PrSiAs3', 'PrSiP3', 'ScSi3Ni', 'SiH3F', 'SiH3I', 'SiPbO3', 'SmCoSi3', 'SmSi3Ir', 'SmSi3Ni', 'SmSi3Os', 'SmSi3Rh', 'Sr3SiO', 'SrSi3Au', 'SrSi3Ni', 'SrSiO3', 'TbCoSi3', 'TbSi3Ir', 'TbSi3Rh', 'ThCoSi3', 'ThSi3Ir', 'ThSi3Os', 'ThSi3Rh', 'ThSi3Ru', 'LaCoSi3', 'LaSi3Ir', 'LaSi3Os', 'LaSi3Rh', 'LaSi3Ru', 'LaSiAs3', 'LiSi3Pd', 'MgSiO3', 'Mn3SiIr', 'MnSiO3', 'NaSiAu3', 'NdCoSi3']
# Si has 73 repetitions
#
#
#
# F: ['AlFe3C', 'AlFeO3', 'AsCF3', 'BaFeO3', 'BaLiF3', 'BeNF3', 'CBr3F', 'CCl3F', 'CClF3', 'CIF3', 'CaFeO3', 'CdNF3', 'CeFeGe3', 'CrFeO3', 'CrOF3', 'CsAgF3', 'CsBeF3', 'CsCaF3', 'CsCdF3', 'CsCoF3', 'CsEuF3', 'CsFeBr3', 'CsFeCl3', 'CsFeF3', 'CsHgF3', 'CsMgF3', 'CsMnF3', 'CsNiF3', 'CsPbF3', 'CsSnF3', 'CsSrF3', 'CsTlF3', 'CuAgF3', 'DyFeO3', 'ErFeO3', 'EuFeO3', 'Fe3NiN', 'Fe3PdN', 'Fe3PtN', 'Fe3RhN', 'Fe3SnC', 'FeBO3', 'FeBiO3', 'FeCO3', 'FeGeO3', 'FeNCl3', 'FePS3', 'FePSe3', 'FeSO3', 'FeSiO3', 'GaFeO3', 'GdFeO3', 'H3OF', 'HoFeO3', 'IOF3', 'InFeBr3', 'InFeO3', 'KAgF3', 'KCaF3', 'KCdF3', 'KCoF3', 'KCrF3', 'KCuF3', 'KFeBr3', 'KFeCl3', 'KFeF3', 'KHgF3', 'KMgF3', 'KMnF3', 'KNiF3', 'KPdF3', 'KSnF3', 'KVF3', 'KZnF3', 'TiFeO3', 'TlFeBr3', 'TlFeI3', 'TlFeO3', 'TmFeO3', 'UFeS3', 'UFeSe3', 'YFeO3', 'ZnAgF3', 'ZnFe3C', 'NiNF3', 'PCF3', 'PrFeGe3', 'PrFeO3', 'PrFeSb3', 'RbAgF3', 'RbCaF3', 'RbCdF3', 'RbCoF3', 'RbCuF3', 'RbFeF3', 'RbHgF3', 'RbMgF3', 'RbMnF3', 'RbNiF3', 'RbPbF3', 'RbPdF3', 'RbSnF3', 'RbVF3', 'RbZnF3', 'ReO3F', 'SiH3F', 'SmFeO3', 'SmFeSb3', 'SnNF3', 'SrFeO3', 'TaFeTe3', 'TbFeO3', 'TbFeSb3', 'TcO3F', 'TeCF3', 'LaFeGe3', 'LaFeO3', 'LuFeO3', 'MnNF3', 'NaCoF3', 'NaCuF3', 'NaFeF3', 'NaMgF3', 'NaMnF3', 'NaNiF3', 'NaVF3', 'NaZnF3', 'NdFeO3', 'NdFeSb3']
# F has 129 repetitions
#
#
#
# Au: ['AuNCl3', 'BaSn3Au', 'Ca3AuN', 'CaGaAu3', 'CeAl3Au', 'Cs3AuO', 'CsAuBr3', 'CsAuCl3', 'CsAuI3', 'CsAuSe3', 'Cu3SnAu', 'K3AuO', 'KAuI3', 'V3AuN', 'Rb3AuO', 'RbAuBr3', 'RbAuI3', 'SrGeAu3', 'SrSi3Au', 'LaAl3Au', 'LaAuO3', 'NaGeAu3', 'NaSiAu3']
# Au has 23 repetitions
#
#
#
# Ba: ['Ba3BiN', 'Ba3GeO', 'Ba3LiN', 'Ba3NaN', 'Ba3PbO', 'Ba3SbN', 'Ba3SnO', 'BaBiO3', 'BaBiSe3', 'BaCO3', 'BaCaSn3', 'BaCeO3', 'BaClO3', 'BaCoO3', 'BaCrO3', 'BaFeO3', 'BaGe3Ir', 'BaGe3Pd', 'BaGe3Pt', 'BaGe3Rh', 'BaGeO3', 'BaGeS3', 'BaHfS3', 'BaIrO3', 'BaLiF3', 'BaLiH3', 'BaMnO3', 'BaMoO3', 'BaN3Cl', 'BaNbO3', 'BaNiO3', 'BaNiSn3', 'BaNpO3', 'BaOsO3', 'BaPS3', 'BaPSe3', 'BaPaO3', 'BaPbO3', 'BaPrO3', 'BaPuO3', 'BaRhO3', 'BaRuO3', 'BaSbTe3', 'BaSeO3', 'BaSi3Pd', 'BaSi3Pt', 'BaSiO3', 'BaSn3Au', 'BaSn3Pd', 'BaSn3Pt', 'BaSnO3', 'BaSnS3', 'BaTaS3', 'BaTaSe3', 'BaTbO3', 'BaTcO3', 'BaTeO3', 'BaTeS3', 'BaThO3', 'BaTiO3', 'BaTiS3', 'BaTiSe3', 'BaUS3', 'BaVO3', 'BaVS3', 'BaVSe3', 'BaZrO3', 'BaZrS3', 'BaZrSe3']
# Ba has 69 repetitions
#
#
#
# Ge: ['Ba3GeO', 'BaGe3Ir', 'BaGe3Pd', 'BaGe3Pt', 'BaGe3Rh', 'BaGeO3', 'BaGeS3', 'Ca3GeN', 'Ca3GeO', 'CaGeO3', 'CdGeO3', 'CeCoGe3', 'CeCrGe3', 'CeFeGe3', 'CeGe3Ir', 'CeGe3Rh', 'CeGe3Ru', 'CoGeO3', 'Cr3GeC', 'Cr3GeN', 'CrGeTe3', 'CsGeBr3', 'CsGeCl3', 'CsGeI3', 'CuGeO3', 'DyNiGe3', 'ErNiGe3', 'EuCoGe3', 'EuGe3Ir', 'EuGe3Pd', 'EuGe3Pt', 'EuGe3Rh', 'EuGeS3', 'EuNiGe3', 'FeGeO3', 'GdNiGe3', 'GeH3Cl', 'GeNCl3', 'GePbO3', 'GePbS3', 'GePdS3', 'HoNiGe3', 'TiGeS3', 'TlGeI3', 'TmNiGe3', 'V3GeC', 'V3GeN', 'YNiGe3', 'ZnGeO3', 'NdVGe3', 'Ni3GeC', 'PrCoGe3', 'PrCrGe3', 'PrFeGe3', 'PrGe3Rh', 'PrNiGe3', 'PrVGe3', 'RbGeBr3', 'RbGeCl3', 'RbGeI3', 'SmCrGe3', 'SmNiGe3', 'SnGeS3', 'Sr3GeO', 'SrGe3Ir', 'SrGe3Pd', 'SrGe3Pt', 'SrGeAu3', 'SrGeO3', 'TbNiGe3', 'LaCoGe3', 'LaCrGe3', 'LaFeGe3', 'LaGe3Ir', 'LaGe3Os', 'LaGe3Rh', 'LaGe3Ru', 'LaTiGe3', 'LaVGe3', 'LuNiGe3', 'MgGeO3', 'Mn3GeC', 'Mn3GeIr', 'MnGeO3', 'NaGeAu3', 'NdCoGe3', 'NdCrGe3', 'NdNiGe3']
# Ge has 88 repetitions
#
#
#
# Li: ['Ba3LiN', 'BaLiF3', 'BaLiH3', 'SrLiH3', 'Li3BrO', 'LiAsO3', 'LiBPt3', 'LiBiO3', 'LiBrO3', 'LiCaAl3', 'LiEuH3', 'LiGaBr3', 'LiGaCl3', 'LiGaI3', 'LiIO3', 'LiNO3', 'LiNbO3', 'LiOsO3', 'LiPO3', 'LiReO3', 'LiSbO3', 'LiScI3', 'LiSi3Pd', 'LiTaO3', 'LiUO3', 'LiVO3']
# Li has 26 repetitions
#
#
#
# Na: ['Ba3NaN', 'Na3ClO', 'NaAsO3', 'NaBPt3', 'NaBiO3', 'NaBrO3', 'NaCO3', 'NaClO3', 'NaCoF3', 'NaCuF3', 'NaFeF3', 'NaGeAu3', 'NaHgCl3', 'NaIO3', 'NaIrO3', 'NaMgF3', 'NaMgH3', 'NaMnCl3', 'NaMnF3', 'NaNO3', 'NaNbO3', 'NaNiF3', 'NaOsO3', 'NaPO3', 'NaPS3', 'NaSbO3', 'NaSeO3', 'NaSiAu3', 'NaTaO3', 'NaUO3', 'NaVF3', 'NaVO3', 'NaWO3', 'NaZnF3', 'NaZnO3']
# Na has 35 repetitions
#
#
#
# Pb: ['Ba3PbO', 'BaPbO3', 'BiPtPb3', 'Ca3PbN', 'Ca3PbO', 'CaPbO3', 'Ce3PbC', 'CrPbO3', 'CsPbBr3', 'CsPbCl3', 'CsPbF3', 'CsPbI3', 'Dy3PbC', 'Er3PbC', 'Gd3PbC', 'GePbO3', 'GePbS3', 'HfPbO3', 'HfPbS3', 'La3PbC', 'TiPbO3', 'TlPbI3', 'Tm3PbC', 'VPbO3', 'Y3PbC', 'ZnPbO3', 'ZrPbO3', 'ZrPbS3', 'OsPbO3', 'PPbO3', 'PPbSe3', 'PbCO3', 'PbSO3', 'PbSeO3', 'Pd3PbC', 'Pr3PbC', 'Pt3PbC', 'RbPbF3', 'RbPbI3', 'Sc3BPb', 'Sc3PbC', 'SiPbO3', 'Sm3PbC', 'SnPbO3', 'SnPbS3', 'Sr3PbO', 'SrPbO3', 'Tb3PbC', 'TcPbO3', 'TePbO3', 'MnPbO3', 'Nd3PbC', 'Nd3PbN']
# Pb has 53 repetitions
#
#
#
# Sn: ['Ba3SnO', 'BaCaSn3', 'BaNiSn3', 'BaSn3Au', 'BaSn3Pd', 'BaSn3Pt', 'BaSnO3', 'BaSnS3', 'Ca3SnN', 'Ca3SnO', 'CaSnO3', 'CdSnO3', 'Ce3SnC', 'CeSn3Ru', 'Co3SnC', 'Cr3SnN', 'CsSnBr3', 'CsSnCl3', 'CsSnF3', 'CsSnI3', 'CsSnS3', 'CsSnSe3', 'Cu3SnAu', 'Dy3SnC', 'Er3SnC', 'Fe3SnC', 'HfSnS3', 'Ho3SnC', 'KSnF3', 'KSnN3', 'Tm3SnC', 'Y3SnC', 'ZnSnO3', 'ZrSnS3', 'NdSn3Ru', 'Pr3SnC', 'PrSn3Ru', 'RbSnF3', 'RbSnI3', 'Sc3SnB', 'Sc3SnC', 'Sm3SnC', 'SmSn3Ru', 'SnCCl3', 'SnGeS3', 'SnHgO3', 'SnNF3', 'SnPO3', 'SnPS3', 'SnPSe3', 'SnPbO3', 'SnPbS3', 'SnPt3C', 'Sr3SnO', 'SrNiSn3', 'SrSn3Pd', 'SrSnO3', 'SrSnS3', 'TaSnO3', 'Tb3SnC', 'Ti3SnH', 'LaSn3Ru', 'Lu3SnC', 'Mn3SnC', 'Mn3SnN', 'MnSnO3', 'Nd3SnC', 'Nd3SnN']
# Sn has 68 repetitions
#
#
#
# Ca: ['BaCaSn3', 'Ca3AsN', 'Ca3AuN', 'Ca3BiN', 'Ca3GeN', 'Ca3GeO', 'Ca3PN', 'Ca3PbN', 'Ca3PbO', 'Ca3SbN', 'Ca3SiO', 'Ca3SnN', 'Ca3SnO', 'Ca3TlN', 'CaBO3', 'CaCO3', 'CaCrO3', 'CaFeO3', 'CaGaAu3', 'CaGeO3', 'CaHfS3', 'CaInBr3', 'CaIrO3', 'CaMnO3', 'CaMoO3', 'CaNCl3', 'CaNbO3', 'CaNiH3', 'CaPS3', 'CaPSe3', 'CaPbO3', 'CaPd3C', 'CaPtO3', 'CaRhO3', 'CaRuO3', 'CaSeO3', 'CaSi3Ir', 'CaSi3Pt', 'CaSiO3', 'CaSnO3', 'CaTcO3', 'CaTeO3', 'CaTiO3', 'CaVO3', 'CaZrO3', 'CaZrS3', 'CsCaBr3', 'CsCaF3', 'CsCaH3', 'KCaF3', 'RbCaF3', 'RbCaH3', 'LiCaAl3']
# Ca has 53 repetitions
#
#
#
# Ce: ['BaCeO3', 'Ce3AlC', 'Ce3AlN', 'Ce3InC', 'Ce3PbC', 'Ce3SnC', 'Ce3TlC', 'CeAl3Au', 'CeAl3Cu', 'CeAlO3', 'CeAsO3', 'CeBO3', 'CeBPd3', 'CeBPt3', 'CeBRh3', 'CeBS3', 'CeCoGe3', 'CeCoSb3', 'CeCrGe3', 'CeCrO3', 'CeCrS3', 'CeCrSe3', 'CeDyS3', 'CeErS3', 'CeFeGe3', 'CeGa3Pd', 'CeGaO3', 'CeGe3Ir', 'CeGe3Rh', 'CeGe3Ru', 'CeLuS3', 'CeNiSb3', 'CeRh3C', 'CeSb3Pd', 'CeScO3', 'CeScS3', 'CeSi3Ir', 'CeSi3Os', 'CeSi3Rh', 'CeSi3Ru', 'CeSiAs3', 'CeSiP3', 'CeSn3Ru', 'CeTmS3', 'CeVO3', 'SrCeO3']
# Ce has 46 repetitions
#
#
#
# Cr: ['BaCrO3', 'CaCrO3', 'CeCrGe3', 'CeCrO3', 'CeCrS3', 'CeCrSe3', 'Cr3AsC', 'Cr3AsN', 'Cr3GaN', 'Cr3GeC', 'Cr3GeN', 'Cr3IrN', 'Cr3PC', 'Cr3PN', 'Cr3PdN', 'Cr3PtN', 'Cr3RhN', 'Cr3SnN', 'CrBO3', 'CrBiO3', 'CrCl3O', 'CrFeO3', 'CrGaSe3', 'CrGeTe3', 'CrInBr3', 'CrInO3', 'CrOF3', 'CrPSe3', 'CrPbO3', 'CrSbS3', 'CrSbSe3', 'CrSiTe3', 'CsCrBr3', 'CsCrCl3', 'CsCrI3', 'DyCrO3', 'ErCrO3', 'EuCrO3', 'GdCrO3', 'HoCrO3', 'KCrF3', 'TlCrO3', 'TmCrO3', 'UCrS3', 'UCrSe3', 'YCrO3', 'PrCrGe3', 'PrCrO3', 'RbCrCl3', 'RbCrI3', 'ScCrO3', 'SmCrGe3', 'SmCrO3', 'SmCrS3', 'SrCrO3', 'TbCrO3', 'ThCrS3', 'ThCrSe3', 'LaCrGe3', 'LaCrO3', 'LaCrS3', 'LaCrSb3', 'LaCrSe3', 'LuCrO3', 'NdCrGe3', 'NdCrO3', 'NdCrS3']
# Cr has 67 repetitions
#
#
#
# Ir: ['BaGe3Ir', 'BaIrO3', 'CaIrO3', 'CaSi3Ir', 'CeGe3Ir', 'CeSi3Ir', 'Cr3IrN', 'DySi3Ir', 'EuGe3Ir', 'EuSi3Ir', 'GdSi3Ir', 'HoSi3Ir', 'KIrO3', 'USi3Ir', 'YSi3Ir', 'NdSi3Ir', 'ScBIr3', 'ScIr3C', 'SmSi3Ir', 'SrGe3Ir', 'SrIrO3', 'TbSi3Ir', 'ThSi3Ir', 'LaGe3Ir', 'LaSi3Ir', 'Mn3GeIr', 'Mn3IrN', 'Mn3SiIr', 'NaIrO3']
# Ir has 29 repetitions
#
#
#
# Rh: ['BaGe3Rh', 'BaRhO3', 'BiRhO3', 'CaRhO3', 'CeBRh3', 'CeGe3Rh', 'CeRh3C', 'CeSi3Rh', 'Cr3RhN', 'DyBRh3', 'DyRh3C', 'ErBRh3', 'ErRh3C', 'EuBRh3', 'EuGe3Rh', 'EuRh3C', 'EuRhO3', 'EuSi3Rh', 'Fe3RhN', 'GdBRh3', 'GdRh3C', 'HfBRh3', 'HoBRh3', 'HoRh3C', 'InRhO3', 'TmBRh3', 'TmRh3C', 'UBRh3', 'URhS3', 'YBRh3', 'YRh3C', 'ZrBRh3', 'NdRh3C', 'NdRhO3', 'NdSi3Rh', 'PrBRh3', 'PrGe3Rh', 'PrRh3C', 'PrRhO3', 'PuRh3C', 'ScBRh3', 'ScRh3C', 'ScRhO3', 'SmBRh3', 'SmRh3C', 'SmRhO3', 'SmSi3Rh', 'TbBRh3', 'TbRh3C', 'TbRhO3', 'TbSi3Rh', 'ThSi3Rh', 'LaBRh3', 'LaGe3Rh', 'LaRhO3', 'LaSi3Rh', 'LuBRh3', 'LuRh3C', 'LuRhO3', 'Mn3RhN', 'NdBRh3']
# Rh has 61 repetitions
#
#
#
# Hf: ['BaHfS3', 'CaHfS3', 'EuHfS3', 'Hf3AlN', 'HfBRh3', 'HfPbO3', 'HfPbS3', 'HfSnS3', 'SrHfO3', 'SrHfS3']
# Hf has 10 repetitions
#
#
#
# H: ['BaHfS3', 'BaLiH3', 'CaHfS3', 'CaNiH3', 'CsCaH3', 'CsHgBr3', 'CsHgCl3', 'CsHgF3', 'CsMgH3', 'EuH3Pd', 'EuHfS3', 'GeH3Cl', 'H3CBr', 'H3CCl', 'H3CI', 'H3CS', 'H3CSe', 'H3NCl', 'H3OF', 'HIO3', 'HNO3', 'HS3N', 'Hf3AlN', 'HfBRh3', 'HfPbO3', 'HfPbS3', 'HfSnS3', 'Hg3ClO', 'HgBrO3', 'HgClO3', 'HgNCl3', 'HgNO3', 'HgPS3', 'HgPSe3', 'HgSN3', 'HgSeO3', 'HgTeO3', 'Ho3AlC', 'Ho3GaC', 'Ho3GaNi', 'Ho3InC', 'Ho3InN', 'Ho3SnC', 'Ho3TlC', 'HoAlO3', 'HoBPd3', 'HoBRh3', 'HoCoO3', 'HoCrO3', 'HoFeO3', 'HoGa3Ru', 'HoGaO3', 'HoMnO3', 'HoNiGe3', 'HoNiO3', 'HoRh3C', 'HoScO3', 'HoScS3', 'HoSi3Ir', 'HoVO3', 'KHgF3', 'KHgI3', 'KMgH3', 'KSiH3', 'TiHgO3', 'TlHPd3', 'TlHgCl3', 'VHgO3', 'ZrCoH3', 'ZrNiH3', 'RbCaH3', 'RbHgF3', 'RbMgH3', 'SiH3F', 'SiH3I', 'SnHgO3', 'SrAlH3', 'SrHfO3', 'SrHfS3', 'SrLiH3', 'TeHO3', 'Ti3SnH', 'LaHoO3', 'LaHoS3', 'LiEuH3', 'NaHgCl3', 'NaMgH3']
# H has 87 repetitions
#
#
#
# Mn: ['BaMnO3', 'CaMnO3', 'CsMnBr3', 'CsMnCl3', 'CsMnF3', 'CsMnI3', 'DyMnO3', 'ErMnO3', 'EuMnO3', 'GdMnO3', 'HoMnO3', 'KMnBr3', 'KMnCl3', 'KMnF3', 'TiMnO3', 'TmMnO3', 'UMnSe3', 'YMnO3', 'PrMnO3', 'RbMnBr3', 'RbMnCl3', 'RbMnF3', 'ScMnO3', 'SmMnO3', 'SrMnO3', 'TbMnO3', 'ThMnSe3', 'LaMnO3', 'LuMnO3', 'Mn3AgN', 'Mn3AlC', 'Mn3CuN', 'Mn3GaC', 'Mn3GaN', 'Mn3GeC', 'Mn3GeIr', 'Mn3InC', 'Mn3IrN', 'Mn3NiN', 'Mn3PdN', 'Mn3PtN', 'Mn3RhN', 'Mn3SiIr', 'Mn3SnC', 'Mn3SnN', 'Mn3ZnC', 'Mn3ZnN', 'MnBiO3', 'MnCO3', 'MnClO3', 'MnCoO3', 'MnGeO3', 'MnInBr3', 'MnInO3', 'MnNCl3', 'MnNF3', 'MnNiO3', 'MnPS3', 'MnPSe3', 'MnPbO3', 'MnSO3', 'MnSeO3', 'MnSiO3', 'MnSnO3', 'MnTlCl3', 'MnTlI3', 'MnVO3', 'NaMnCl3', 'NaMnF3', 'NdMnO3']
# Mn has 70 repetitions
#
#
#
# Mo: ['BaMoO3', 'CaMoO3', 'ErB3Mo', 'SrMoO3', 'MoCl3O', 'MoNCl3']
# Mo has 6 repetitions
#
#
#
# Nb: ['BaNbO3', 'CaNbO3', 'CsNbO3', 'EuNbO3', 'KNbO3', 'RbNbO3', 'SrNbO3', 'LiNbO3', 'NaNbO3', 'NbAgO3', 'NbBr3O', 'NbCl3O', 'NbCuO3', 'NbI3O', 'NbRu3C', 'NbSeBr3', 'NbSeCl3', 'NbSeI3', 'NbTeBr3', 'NbTeI3']
# Nb has 20 repetitions
#
#
#
# Ni: ['BaNiO3', 'BaNiSn3', 'CaNiH3', 'CdNi3N', 'CeNiSb3', 'CsNiBr3', 'CsNiCl3', 'CsNiF3', 'DyNiGe3', 'DyNiO3', 'ErNiGe3', 'ErNiO3', 'ErSi3Ni', 'EuNiGe3', 'EuNiO3', 'Fe3NiN', 'GdNiGe3', 'GdNiO3', 'Ho3GaNi', 'HoNiGe3', 'HoNiO3', 'InNi3N', 'KNiCl3', 'KNiF3', 'TiNiO3', 'TlNiO3', 'TmNiGe3', 'TmNiO3', 'UGa3Ni', 'UNiS3', 'UNiSe3', 'YAl3Ni', 'YNiGe3', 'YNiO3', 'YSi3Ni', 'ZnNi3C', 'Zr3NiO', 'ZrNiH3', 'Ni3GeC', 'NiBiO3', 'NiCO3', 'NiNF3', 'NiPS3', 'NiPSe3', 'NiSeO3', 'PrNiGe3', 'PrNiO3', 'PrNiSb3', 'RbNiBr3', 'RbNiCl3', 'RbNiF3', 'ScSi3Ni', 'SmNiGe3', 'SmNiO3', 'SmNiSb3', 'SmSi3Ni', 'SrNiSn3', 'SrSi3Ni', 'TbNiGe3', 'LaNi3B', 'LaNiO3', 'LaNiSb3', 'LuNiGe3', 'LuNiO3', 'MgNi3C', 'Mn3NiN', 'MnNiO3', 'NaNiF3', 'NdNiGe3', 'NdNiO3', 'NdNiSb3']
# Ni has 71 repetitions
#
#
#
# Os: ['BaOsO3', 'CeSi3Os', 'NdSi3Os', 'OsPbO3', 'SmSi3Os', 'SrOsO3', 'TbGa3Os', 'ThSi3Os', 'LaGe3Os', 'LaSi3Os', 'LiOsO3', 'NaOsO3']
# Os has 12 repetitions
#
#
#
# Pa: ['BaPaO3', 'PaBr3O']
# Pa has 2 repetitions
#
#
#
# Pr: ['BaPrO3', 'Pr3AlC', 'Pr3AlN', 'Pr3GaC', 'Pr3InC', 'Pr3InN', 'Pr3InO', 'Pr3PbC', 'Pr3SnC', 'Pr3TlC', 'PrAl3Cu', 'PrAlO3', 'PrBO3', 'PrBPd3', 'PrBPt3', 'PrBRh3', 'PrBS3', 'PrCoGe3', 'PrCoO3', 'PrCoSb3', 'PrCrGe3', 'PrCrO3', 'PrErS3', 'PrFeGe3', 'PrFeO3', 'PrFeSb3', 'PrGaO3', 'PrGe3Rh', 'PrInO3', 'PrLuO3', 'PrLuSe3', 'PrMnO3', 'PrNiGe3', 'PrNiO3', 'PrNiSb3', 'PrRh3C', 'PrRhO3', 'PrRuO3', 'PrScO3', 'PrSiAs3', 'PrSiP3', 'PrSn3Ru', 'PrTmS3', 'PrVGe3', 'PrVO3', 'SrPrO3']
# Pr has 46 repetitions
#
#
#
# Pu: ['BaPuO3', 'PuRh3C', 'PuRu3C']
# Pu has 3 repetitions
#
#
#
# Ru: ['BaRuO3', 'CaRuO3', 'CeGe3Ru', 'CeSi3Ru', 'CeSn3Ru', 'DyGa3Ru', 'ErGa3Ru', 'GdGa3Ru', 'HoGa3Ru', 'TmGa3Ru', 'URuS3', 'VRu3C', 'YGa3Ru', 'ZrRu3C', 'NdSi3Ru', 'NdSn3Ru', 'PrRuO3', 'PrSn3Ru', 'PuRu3C', 'ScRu3C', 'SmSn3Ru', 'SrRuO3', 'TaRu3C', 'TbGa3Ru', 'ThRu3C', 'ThSi3Ru', 'LaGe3Ru', 'LaRuO3', 'LaSi3Ru', 'LaSn3Ru', 'NbRu3C']
# Ru has 31 repetitions
#
#
#
# Ta: ['BaTaS3', 'BaTaSe3', 'KTaO3', 'KTaTe3', 'RbTaO3', 'TaAgO3', 'TaAgS3', 'TaCuS3', 'TaFeTe3', 'TaRu3C', 'TaSnO3', 'TaTlS3', 'TaTlSe3', 'ThTaN3', 'LiTaO3', 'NaTaO3']
# Ta has 16 repetitions
#
#
#
# Tb: ['BaTbO3', 'SrTbO3', 'Tb3AlC', 'Tb3InC', 'Tb3InN', 'Tb3PbC', 'Tb3SnC', 'Tb3TlC', 'TbAlO3', 'TbBPd3', 'TbBRh3', 'TbBS3', 'TbCoO3', 'TbCoSi3', 'TbCrO3', 'TbFeO3', 'TbFeSb3', 'TbGa3Os', 'TbGa3Ru', 'TbMnO3', 'TbNiGe3', 'TbRh3C', 'TbRhO3', 'TbScO3', 'TbSi3Ir', 'TbSi3Rh', 'TbVO3']
# Tb has 27 repetitions
#
#
#
# Tc: ['BaTcO3', 'CaTcO3', 'CdTcO3', 'KTcCl3', 'SrTcO3', 'TcO3F', 'TcPbO3']
# Tc has 7 repetitions
#
#
#
# Th: ['BaThO3', 'ThCoSi3', 'ThCrS3', 'ThCrSe3', 'ThMnSe3', 'ThRu3C', 'ThSi3Ir', 'ThSi3Os', 'ThSi3Rh', 'ThSi3Ru', 'ThTaN3']
# Th has 11 repetitions
#
#
#
# Ti: ['BaTiO3', 'BaTiS3', 'BaTiSe3', 'CaTiO3', 'CsTiBr3', 'CsTiCl3', 'CsTiI3', 'EuTiO3', 'GdTiO3', 'KTiBr3', 'KTiCl3', 'KTiI3', 'KTiO3', 'Ti3TlN', 'TiBO3', 'TiCdO3', 'TiCoO3', 'TiFeO3', 'TiGeS3', 'TiHgO3', 'TiMnO3', 'TiNiO3', 'TiPbO3', 'TiZnO3', 'YTiO3', 'NdTiO3', 'RbTiBr3', 'RbTiCl3', 'RbTiI3', 'SmTiO3', 'SrTiO3', 'SrTiS3', 'Ti3AlC', 'Ti3AlN', 'Ti3InC', 'Ti3InN', 'Ti3SnH', 'Ti3TlC', 'LaTiGe3', 'LaTiO3', 'MgTiO3']
# Ti has 41 repetitions
#
#
#
# U: ['BaUS3', 'KUO3', 'UBRh3', 'UCoSe3', 'UCrS3', 'UCrSe3', 'UFeS3', 'UFeSe3', 'UGa3Ni', 'UMnSe3', 'UNiS3', 'UNiSe3', 'UPdSe3', 'UReB3', 'URhS3', 'URuS3', 'USi3Ir', 'UVSe3', 'RbUO3', 'ScUS3', 'LiUO3', 'NaUO3']
# U has 22 repetitions
#
#
#
# V: ['BaVO3', 'BaVS3', 'BaVSe3', 'CaVO3', 'CeVO3', 'CsVBr3', 'CsVCl3', 'CsVI3', 'CsVO3', 'DyVO3', 'ErVO3', 'GdVO3', 'HoVO3', 'KVF3', 'KVO3', 'TlVO3', 'TmVO3', 'UVSe3', 'V3AsC', 'V3AsN', 'V3AuN', 'V3GaN', 'V3GeC', 'V3GeN', 'V3PC', 'V3PN', 'VAgO3', 'VBO3', 'VCdO3', 'VCl3O', 'VCoB3', 'VCuO3', 'VHgO3', 'VNO3', 'VPS3', 'VPbO3', 'VRu3C', 'YVO3', 'NdVGe3', 'NdVO3', 'PrVGe3', 'PrVO3', 'RbVBr3', 'RbVCl3', 'RbVF3', 'RbVI3', 'RbVO3', 'SmVO3', 'SrVO3', 'TbVO3', 'LaVGe3', 'LaVO3', 'LiVO3', 'LuVO3', 'MgVO3', 'MnVO3', 'NaVF3', 'NaVO3']
# V has 58 repetitions
#
#
#
# Zr: ['BaZrO3', 'BaZrS3', 'BaZrSe3', 'CaZrO3', 'CaZrS3', 'EuZrO3', 'EuZrS3', 'EuZrSe3', 'Zr3AlN', 'Zr3NiO', 'ZrBRh3', 'ZrCoH3', 'ZrNiH3', 'ZrPbO3', 'ZrPbS3', 'ZrRu3C', 'ZrSnS3', 'SrZrO3', 'SrZrS3', 'SrZrSe3']
# Zr has 20 repetitions
#
#
#
# Be: ['BeNF3', 'CsBeF3']
# Be has 2 repetitions
#
#
#
# Tl: ['Ca3TlN', 'Ce3TlC', 'CsTlF3', 'Dy3TlC', 'Er3TlC', 'Ho3TlC', 'La3TlC', 'Ti3TlN', 'TlBS3', 'TlBSe3', 'TlBrO3', 'TlCdBr3', 'TlCdCl3', 'TlCdI3', 'TlClO3', 'TlCoCl3', 'TlCrO3', 'TlCuCl3', 'TlFeBr3', 'TlFeI3', 'TlFeO3', 'TlGeI3', 'TlHPd3', 'TlHgCl3', 'TlIO3', 'TlNO3', 'TlNiO3', 'TlPO3', 'TlPS3', 'TlPbI3', 'TlSbO3', 'TlVO3', 'Tm3TlC', 'Y3TlC', 'Pr3TlC', 'Sc3TlB', 'Sc3TlC', 'Sm3TlC', 'TaTlS3', 'TaTlSe3', 'Tb3TlC', 'Ti3TlC', 'LaTlO3', 'Lu3TlC', 'MnTlCl3', 'MnTlI3', 'Nd3TlC', 'Nd3TlN']
# Tl has 48 repetitions
#
#
#
# Ga: ['CaGaAu3', 'CeGa3Pd', 'CeGaO3', 'Cr3GaN', 'CrGaSe3', 'CsGaS3', 'CsGaSe3', 'Dy3GaC', 'DyGa3Ru', 'DyGaO3', 'Er3GaC', 'ErGa3Ru', 'EuGa3Pd', 'GaBO3', 'GaBiO3', 'GaFeO3', 'GaPt3C', 'GdGa3Ru', 'GdGaO3', 'Ho3GaC', 'Ho3GaNi', 'HoGa3Ru', 'HoGaO3', 'InGaO3', 'InGaS3', 'Tm3GaC', 'TmGa3Ru', 'UGa3Ni', 'V3GaN', 'Y3GaC', 'YGa3Ru', 'YGaO3', 'Pr3GaC', 'PrGaO3', 'Sc3GaC', 'Sm3GaC', 'SrGa3Pd', 'TbGa3Os', 'TbGa3Ru', 'LaGaO3', 'LaGaS3', 'LiGaBr3', 'LiGaCl3', 'LiGaI3', 'Mn3GaC', 'Mn3GaN', 'Nd3GaC', 'Nd3GaN', 'NdGaO3']
# Ga has 49 repetitions
#
#
#
# In: ['CaInBr3', 'CdInBr3', 'Ce3InC', 'CrInBr3', 'CrInO3', 'Dy3InC', 'Dy3InN', 'Er3InC', 'Er3InN', 'Eu3InO', 'Gd3InC', 'Gd3InN', 'Ho3InC', 'Ho3InN', 'InBO3', 'InBiO3', 'InCo3N', 'InFeBr3', 'InFeO3', 'InGaO3', 'InGaS3', 'InNi3N', 'InPt3C', 'InRhO3', 'InSbS3', 'InSiTe3', 'KInBr3', 'La3InB', 'La3InC', 'La3InN', 'Tm3InC', 'Tm3InN', 'Y3InC', 'YInO3', 'Pr3InC', 'Pr3InN', 'Pr3InO', 'PrInO3', 'Sc3InB', 'Sc3InC', 'Sc3InN', 'Sm3InC', 'Sm3InN', 'SrMgIn3', 'Tb3InC', 'Tb3InN', 'Ti3InC', 'Ti3InN', 'LaInO3', 'Lu3InN', 'MgInBr3', 'Mn3InC', 'MnInBr3', 'MnInO3', 'Nd3InC', 'Nd3InN']
# In has 56 repetitions
#
#
#
# Cd: ['CdCO3', 'CdCo3N', 'CdGeO3', 'CdInBr3', 'CdNCl3', 'CdNF3', 'CdNi3N', 'CdPS3', 'CdPSe3', 'CdSO3', 'CdSeO3', 'CdSiO3', 'CdSnO3', 'CdTcO3', 'CdTeO3', 'CsCdBr3', 'CsCdCl3', 'CsCdF3', 'KCdCl3', 'KCdF3', 'TiCdO3', 'TlCdBr3', 'TlCdCl3', 'TlCdI3', 'VCdO3', 'RbCdBr3', 'RbCdCl3', 'RbCdF3']
# Cd has 28 repetitions
#
#
#
# Cu: ['CeAl3Cu', 'CsCuBr3', 'CsCuCl3', 'Cu3SnAu', 'CuAgF3', 'CuCO3', 'CuGeO3', 'CuNCl3', 'CuPS3', 'CuSe3Br', 'CuSe3I', 'CuSeO3', 'CuSiO3', 'CuTeO3', 'GdAl3Cu', 'KCuCl3', 'KCuF3', 'TlCuCl3', 'VCuO3', 'PrAl3Cu', 'RbCuCl3', 'RbCuF3', 'TaCuS3', 'LaAl3Cu', 'LaCuO3', 'Mn3CuN', 'NaCuF3', 'NbCuO3', 'NdAl3Cu']
# Cu has 29 repetitions
#
#
#
# Dy: ['CeDyS3', 'CsDyBr3', 'CsDyI3', 'Dy3AlC', 'Dy3GaC', 'Dy3InC', 'Dy3InN', 'Dy3PbC', 'Dy3SnC', 'Dy3TlC', 'DyAlO3', 'DyBO3', 'DyBPd3', 'DyBRh3', 'DyCoO3', 'DyCrO3', 'DyFeO3', 'DyGa3Ru', 'DyGaO3', 'DyMnO3', 'DyNiGe3', 'DyNiO3', 'DyRh3C', 'DyScO3', 'DySi3Ir', 'DyVO3']
# Dy has 26 repetitions
#
#
#
# Er: ['CeErS3', 'Er3AlC', 'Er3GaC', 'Er3InC', 'Er3InN', 'Er3PbC', 'Er3SnC', 'Er3TlC', 'ErB3Mo', 'ErBO3', 'ErBPd3', 'ErBRh3', 'ErCoO3', 'ErCrO3', 'ErFeO3', 'ErGa3Ru', 'ErMnO3', 'ErNiGe3', 'ErNiO3', 'ErRh3C', 'ErScS3', 'ErSi3Ni', 'ErVO3', 'PrErS3', 'LaErO3', 'LaErS3']
# Er has 26 repetitions
#
#
#
# Lu: ['CeLuS3', 'PrLuO3', 'PrLuSe3', 'LaLuO3', 'Lu3InN', 'Lu3SnC', 'Lu3TlC', 'LuBO3', 'LuBPd3', 'LuBRh3', 'LuCoO3', 'LuCrO3', 'LuFeO3', 'LuMnO3', 'LuNiGe3', 'LuNiO3', 'LuRh3C', 'LuRhO3', 'LuVO3', 'NdLuSe3']
# Lu has 20 repetitions
#
#
#
# Sc: ['CeScO3', 'CeScS3', 'CsScCl3', 'DyScO3', 'ErScS3', 'EuScO3', 'GdScO3', 'GdScS3', 'HoScO3', 'HoScS3', 'YScO3', 'NdScO3', 'PrScO3', 'Sc3AlC', 'Sc3BPb', 'Sc3GaC', 'Sc3InB', 'Sc3InC', 'Sc3InN', 'Sc3PbC', 'Sc3SnB', 'Sc3SnC', 'Sc3TlB', 'Sc3TlC', 'ScAlO3', 'ScBIr3', 'ScBO3', 'ScBRh3', 'ScBiO3', 'ScCo3C', 'ScCrO3', 'ScIr3C', 'ScMnO3', 'ScRh3C', 'ScRhO3', 'ScRu3C', 'ScSi3Ni', 'ScUS3', 'SmScO3', 'TbScO3', 'LaScO3', 'LiScI3']
# Sc has 42 repetitions
#
#
#
# Tm: ['CeTmS3', 'CsTmCl3', 'KTmI3', 'Tm3AlC', 'Tm3GaC', 'Tm3InC', 'Tm3InN', 'Tm3PbC', 'Tm3SnC', 'Tm3TlC', 'TmBO3', 'TmBPd3', 'TmBRh3', 'TmCoO3', 'TmCrO3', 'TmFeO3', 'TmGa3Ru', 'TmMnO3', 'TmNiGe3', 'TmNiO3', 'TmRh3C', 'TmVO3', 'NdTmS3', 'PrTmS3', 'LaTmO3', 'LaTmS3']
# Tm has 26 repetitions
#
#
#
# Cs: ['Cs3AuO', 'Cs3ClO', 'CsAgCl3', 'CsAgF3', 'CsAlTe3', 'CsAuBr3', 'CsAuCl3', 'CsAuI3', 'CsAuSe3', 'CsBSe3', 'CsBeF3', 'CsBrO3', 'CsCaBr3', 'CsCaF3', 'CsCaH3', 'CsCdBr3', 'CsCdCl3', 'CsCdF3', 'CsCoCl3', 'CsCoF3', 'CsCrBr3', 'CsCrCl3', 'CsCrI3', 'CsCuBr3', 'CsCuCl3', 'CsDyBr3', 'CsDyI3', 'CsEuBr3', 'CsEuCl3', 'CsEuF3', 'CsFeBr3', 'CsFeCl3', 'CsFeF3', 'CsGaS3', 'CsGaSe3', 'CsGeBr3', 'CsGeCl3', 'CsGeI3', 'CsHgBr3', 'CsHgCl3', 'CsHgF3', 'CsIO3', 'CsMgBr3', 'CsMgCl3', 'CsMgF3', 'CsMgH3', 'CsMgI3', 'CsMnBr3', 'CsMnCl3', 'CsMnF3', 'CsMnI3', 'CsNO3', 'CsNbO3', 'CsNiBr3', 'CsNiCl3', 'CsNiF3', 'CsPS3', 'CsPbBr3', 'CsPbCl3', 'CsPbF3', 'CsPbI3', 'CsPdCl3', 'CsSO3', 'CsScCl3', 'CsSiTe3', 'CsSmCl3', 'CsSnBr3', 'CsSnCl3', 'CsSnF3', 'CsSnI3', 'CsSnS3', 'CsSnSe3', 'CsSrF3', 'CsTeSe3', 'CsTiBr3', 'CsTiCl3', 'CsTiI3', 'CsTlF3', 'CsTmCl3', 'CsVBr3', 'CsVCl3', 'CsVI3', 'CsVO3']
# Cs has 83 repetitions
#
#
#
# Eu: ['CsEuBr3', 'CsEuCl3', 'CsEuF3', 'Eu3InO', 'EuAlO3', 'EuBO3', 'EuBPd3', 'EuBRh3', 'EuCO3', 'EuCoGe3', 'EuCrO3', 'EuFeO3', 'EuGa3Pd', 'EuGe3Ir', 'EuGe3Pd', 'EuGe3Pt', 'EuGe3Rh', 'EuGeS3', 'EuH3Pd', 'EuHfS3', 'EuMnO3', 'EuNbO3', 'EuNiGe3', 'EuNiO3', 'EuPS3', 'EuPSe3', 'EuRh3C', 'EuRhO3', 'EuScO3', 'EuSi3Ir', 'EuSi3Rh', 'EuTiO3', 'EuZrO3', 'EuZrS3', 'EuZrSe3', 'LiEuH3']
# Eu has 36 repetitions
#
#
#
# Hg: ['CsHgBr3', 'CsHgCl3', 'CsHgF3', 'Hg3ClO', 'HgBrO3', 'HgClO3', 'HgNCl3', 'HgNO3', 'HgPS3', 'HgPSe3', 'HgSN3', 'HgSeO3', 'HgTeO3', 'KHgF3', 'KHgI3', 'TiHgO3', 'TlHgCl3', 'VHgO3', 'RbHgF3', 'SnHgO3', 'NaHgCl3']
# Hg has 21 repetitions
#
#
#
# Mg: ['CsMgBr3', 'CsMgCl3', 'CsMgF3', 'CsMgH3', 'CsMgI3', 'KMgCl3', 'KMgF3', 'KMgH3', 'RbMgCl3', 'RbMgF3', 'RbMgH3', 'SrMgIn3', 'Mg3ZnC', 'MgBO3', 'MgCO3', 'MgCo3C', 'MgGeO3', 'MgInBr3', 'MgNi3C', 'MgPS3', 'MgPSe3', 'MgSeO3', 'MgSiO3', 'MgTiO3', 'MgVO3', 'NaMgF3', 'NaMgH3']
# Mg has 27 repetitions
#
#
#
# Sm: ['CsSmCl3', 'Sm3AlC', 'Sm3AlN', 'Sm3GaC', 'Sm3InC', 'Sm3InN', 'Sm3PbC', 'Sm3SnC', 'Sm3TlC', 'SmAlO3', 'SmBO3', 'SmBPd3', 'SmBRh3', 'SmBS3', 'SmCoO3', 'SmCoSb3', 'SmCoSi3', 'SmCrGe3', 'SmCrO3', 'SmCrS3', 'SmFeO3', 'SmFeSb3', 'SmMnO3', 'SmNiGe3', 'SmNiO3', 'SmNiSb3', 'SmRh3C', 'SmRhO3', 'SmScO3', 'SmSi3Ir', 'SmSi3Ni', 'SmSi3Os', 'SmSi3Rh', 'SmSn3Ru', 'SmTiO3', 'SmVO3']
# Sm has 36 repetitions
#
#
#
# Sr: ['CsSrF3', 'Sr3BiN', 'Sr3GeO', 'Sr3PbO', 'Sr3SbN', 'Sr3SiO', 'Sr3SnO', 'SrAlH3', 'SrBO3', 'SrBiO3', 'SrBiSe3', 'SrCO3', 'SrCeO3', 'SrCoO3', 'SrCrO3', 'SrFeO3', 'SrGa3Pd', 'SrGe3Ir', 'SrGe3Pd', 'SrGe3Pt', 'SrGeAu3', 'SrGeO3', 'SrHfO3', 'SrHfS3', 'SrIrO3', 'SrLiH3', 'SrMgIn3', 'SrMnO3', 'SrMoO3', 'SrNbO3', 'SrNiSn3', 'SrOsO3', 'SrPS3', 'SrPSe3', 'SrPbO3', 'SrPrO3', 'SrRuO3', 'SrSbSe3', 'SrSeO3', 'SrSi3Au', 'SrSi3Ni', 'SrSiO3', 'SrSn3Pd', 'SrSnO3', 'SrSnS3', 'SrTbO3', 'SrTcO3', 'SrTeO3', 'SrTiO3', 'SrTiS3', 'SrVO3', 'SrZrO3', 'SrZrS3', 'SrZrSe3']
# Sr has 54 repetitions
#
#
#
# Gd: ['Gd3AlC', 'Gd3InC', 'Gd3InN', 'Gd3PbC', 'GdAl3Cu', 'GdAlO3', 'GdBO3', 'GdBPd3', 'GdBRh3', 'GdCoSi3', 'GdCrO3', 'GdFeO3', 'GdGa3Ru', 'GdGaO3', 'GdMnO3', 'GdNiGe3', 'GdNiO3', 'GdRh3C', 'GdScO3', 'GdScS3', 'GdSi3Ir', 'GdTiO3', 'GdVO3']
# Gd has 23 repetitions
#
#
#
# Ho: ['Ho3AlC', 'Ho3GaC', 'Ho3GaNi', 'Ho3InC', 'Ho3InN', 'Ho3SnC', 'Ho3TlC', 'HoAlO3', 'HoBPd3', 'HoBRh3', 'HoCoO3', 'HoCrO3', 'HoFeO3', 'HoGa3Ru', 'HoGaO3', 'HoMnO3', 'HoNiGe3', 'HoNiO3', 'HoRh3C', 'HoScO3', 'HoScS3', 'HoSi3Ir', 'HoVO3', 'LaHoO3', 'LaHoS3']
# Ho has 25 repetitions
#
#
#
# K: ['K3AuO', 'K3BrO', 'K3CO', 'K3ClO', 'K3IO', 'KAgF3', 'KAsO3', 'KAuI3', 'KBiO3', 'KBrO3', 'KCO3', 'KCaF3', 'KCdCl3', 'KCdF3', 'KClO3', 'KCoF3', 'KCrF3', 'KCuCl3', 'KCuF3', 'KFeBr3', 'KFeCl3', 'KFeF3', 'KHgF3', 'KHgI3', 'KIO3', 'KInBr3', 'KIrO3', 'KMgCl3', 'KMgF3', 'KMgH3', 'KMnBr3', 'KMnCl3', 'KMnF3', 'KNO3', 'KNbO3', 'KNiCl3', 'KNiF3', 'KPO3', 'KPS3', 'KPSe3', 'KPdF3', 'KSO3', 'KSbO3', 'KSiH3', 'KSiO3', 'KSnF3', 'KSnN3', 'KTaO3', 'KTaTe3', 'KTcCl3', 'KTiBr3', 'KTiCl3', 'KTiI3', 'KTiO3', 'KTmI3', 'KUO3', 'KVF3', 'KVO3', 'KZnF3']
# K has 59 repetitions
#
#
#
# Zn: ['KZnF3', 'TiZnO3', 'ZnAgF3', 'ZnCO3', 'ZnCo3C', 'ZnFe3C', 'ZnGeO3', 'ZnNi3C', 'ZnPS3', 'ZnPbO3', 'ZnSeO3', 'ZnSiO3', 'ZnSnO3', 'ZnTeO3', 'RbZnF3', 'Mg3ZnC', 'Mn3ZnC', 'Mn3ZnN', 'NaZnF3', 'NaZnO3']
# Zn has 20 repetitions
#
#
#
# La: ['La3AlC', 'La3AlN', 'La3InB', 'La3InC', 'La3InN', 'La3PbC', 'La3TlC', 'LaAl3Au', 'LaAl3Cu', 'LaAlO3', 'LaAsO3', 'LaAuO3', 'LaBO3', 'LaBPd3', 'LaBRh3', 'LaCoGe3', 'LaCoO3', 'LaCoSb3', 'LaCoSi3', 'LaCrGe3', 'LaCrO3', 'LaCrS3', 'LaCrSb3', 'LaCrSe3', 'LaCuO3', 'LaErO3', 'LaErS3', 'LaFeGe3', 'LaFeO3', 'LaGaO3', 'LaGaS3', 'LaGe3Ir', 'LaGe3Os', 'LaGe3Rh', 'LaGe3Ru', 'LaHoO3', 'LaHoS3', 'LaIO3', 'LaInO3', 'LaLuO3', 'LaMnO3', 'LaNi3B', 'LaNiO3', 'LaNiSb3', 'LaPdO3', 'LaRhO3', 'LaRuO3', 'LaScO3', 'LaSi3Ir', 'LaSi3Os', 'LaSi3Rh', 'LaSi3Ru', 'LaSiAs3', 'LaSn3Ru', 'LaTiGe3', 'LaTiO3', 'LaTlO3', 'LaTmO3', 'LaTmS3', 'LaVGe3', 'LaVO3', 'LaYO3', 'LaYS3']
# La has 63 repetitions
#
#
#
# Re: ['UReB3', 'ReClO3', 'ReO3F', 'LiReO3']
# Re has 4 repetitions
#
#
#
# W: ['WCl3O', 'WI3O', 'NaWO3']
# W has 3 repetitions
#
#
#
# Y: ['Y3AlC', 'Y3GaC', 'Y3InC', 'Y3PbC', 'Y3SnC', 'Y3TlC', 'YAl3Ni', 'YAlO3', 'YBO3', 'YBRh3', 'YCoO3', 'YCrO3', 'YFeO3', 'YGa3Ru', 'YGaO3', 'YInO3', 'YMnO3', 'YNiGe3', 'YNiO3', 'YRh3C', 'YScO3', 'YSi3Ir', 'YSi3Ni', 'YTiO3', 'YVO3', 'LaYO3', 'LaYS3']
# Y has 27 repetitions
#
#
#
# Nd: ['NdRh3C', 'NdRhO3', 'NdScO3', 'NdSi3Ir', 'NdSi3Os', 'NdSi3Rh', 'NdSi3Ru', 'NdSn3Ru', 'NdTiO3', 'NdTmS3', 'NdVGe3', 'NdVO3', 'Nd3AlC', 'Nd3AlN', 'Nd3GaC', 'Nd3GaN', 'Nd3InC', 'Nd3InN', 'Nd3PbC', 'Nd3PbN', 'Nd3SnC', 'Nd3SnN', 'Nd3TlC', 'Nd3TlN', 'NdAl3Cu', 'NdAlO3', 'NdBO3', 'NdBPd3', 'NdBPt3', 'NdBRh3', 'NdBS3', 'NdCoGe3', 'NdCoO3', 'NdCoSb3', 'NdCoSi3', 'NdCrGe3', 'NdCrO3', 'NdCrS3', 'NdFeO3', 'NdFeSb3', 'NdGaO3', 'NdLuSe3', 'NdMnO3', 'NdNiGe3', 'NdNiO3', 'NdNiSb3']
# Nd has 46 repetitions
#
#
#
# Rb: ['Rb3AuO', 'Rb3BrO', 'Rb3IO', 'RbAgF3', 'RbAuBr3', 'RbAuI3', 'RbBS3', 'RbBSe3', 'RbBrO3', 'RbCO3', 'RbCaF3', 'RbCaH3', 'RbCdBr3', 'RbCdCl3', 'RbCdF3', 'RbClO3', 'RbCoCl3', 'RbCoF3', 'RbCrCl3', 'RbCrI3', 'RbCuCl3', 'RbCuF3', 'RbFeF3', 'RbGeBr3', 'RbGeCl3', 'RbGeI3', 'RbHgF3', 'RbIO3', 'RbMgCl3', 'RbMgF3', 'RbMgH3', 'RbMnBr3', 'RbMnCl3', 'RbMnF3', 'RbNO3', 'RbNbO3', 'RbNiBr3', 'RbNiCl3', 'RbNiF3', 'RbPO3', 'RbPS3', 'RbPSe3', 'RbPbF3', 'RbPbI3', 'RbPdF3', 'RbSO3', 'RbSeO3', 'RbSnF3', 'RbSnI3', 'RbTaO3', 'RbTiBr3', 'RbTiCl3', 'RbTiI3', 'RbUO3', 'RbVBr3', 'RbVCl3', 'RbVF3', 'RbVI3', 'RbVO3', 'RbZnF3']
# Rb has 60 repetitions

# %%
len(repetitive_elements)
# Out:
# 80

# %%
# Function to find elements in A, B, and C
def find_elements(formulas):
    elements_A = set()
    elements_B = set()
    elements_C = set()
    
    # Iterate over each formula
    for formula in formulas:
        # Extract elements from the formula using regular expression
        elements = re.findall('[A-Z][a-z]*', formula)
        if len(elements) == 3:
            elements_A.add(elements[0])
            elements_B.add(elements[1])
            elements_C.add(elements[2])
    
    print("Elements in A:")
    print(elements_A)
    print("Elements in B:")
    print(elements_B)
    print("Elements in C:")
    print(elements_C)

# Find and print elements in A, B, and C
find_elements(chemical_formulas)
# Out:
# Elements in A:
# {'Y', 'Zr', 'Pa', 'Ho', 'Cd', 'Li', 'Ce', 'Pd', 'Tl', 'Pb', 'Ga', 'Mn', 'Be', 'Ge', 'Th', 'In', 'Co', 'Au', 'P', 'Ba', 'Br', 'Tc', 'H', 'Eu', 'Hg', 'Sm', 'Mg', 'Pu', 'Te', 'W', 'Ca', 'Zn', 'Ni', 'Nb', 'K', 'Pt', 'Al', 'Gd', 'U', 'Sc', 'Bi', 'As', 'Cs', 'Os', 'Sn', 'Cu', 'Nd', 'Ta', 'Er', 'V', 'Cr', 'Re', 'Tb', 'Si', 'C', 'Tm', 'Fe', 'N', 'Sr', 'I', 'Na', 'Pr', 'Dy', 'Ti', 'Rb', 'Sb', 'Mo', 'La', 'Lu', 'Ag', 'Hf', 'S'}
# Elements in B:
# {'Pa', 'Zr', 'Y', 'Ho', 'Cd', 'Ce', 'Ru', 'Pd', 'Tl', 'Pb', 'Mn', 'Ga', 'Be', 'Ge', 'Th', 'In', 'Co', 'Au', 'P', 'Br', 'O', 'Tc', 'H', 'Eu', 'Hg', 'Sm', 'Pu', 'Te', 'W', 'Ca', 'Nb', 'Ni', 'Zn', 'Pt', 'Li', 'Al', 'Sc', 'Rh', 'U', 'Bi', 'As', 'Ta', 'Sn', 'Os', 'Cu', 'Hf', 'Tb', 'V', 'Cr', 'Er', 'Re', 'Si', 'Np', 'C', 'Tm', 'Fe', 'S', 'Cl', 'N', 'Sr', 'I', 'Na', 'Ir', 'Pr', 'Dy', 'Ti', 'Sb', 'Mo', 'Mg', 'Lu', 'Ag', 'Se', 'B'}
# Elements in C:
# {'Ru', 'Pd', 'Pb', 'Ge', 'In', 'F', 'Au', 'P', 'Br', 'H', 'Te', 'Ni', 'Pt', 'O', 'Al', 'Rh', 'As', 'Sn', 'Os', 'Cu', 'Si', 'C', 'Cl', 'N', 'I', 'Ir', 'Sb', 'B', 'Mo', 'Se', 'S'}

# %%
# Function to find elements in A, B, and C and print their intersections
def find_elements(formulas):
    elements_A = set()
    elements_B = set()
    elements_C = set()
    
    # Iterate over each formula
    for formula in formulas:
        # Extract elements from the formula using regular expression
        elements = re.findall('[A-Z][a-z]*', formula)
        if len(elements) == 3:
            elements_A.add(elements[0])
            elements_B.add(elements[1])
            elements_C.add(elements[2])
    
    print("Elements in A:")
    print(elements_A)
    print(len(elements_A))
    print("Elements in B:")
    print(elements_B)
    print(len(elements_B))
    print("Elements in C:")
    print(elements_C)
    print(len(elements_C))
    
    print("\nMatching elements:")
    print(f"{len(elements_A.intersection(elements_B))} Elements in A that match with B:")
    print(elements_A.intersection(elements_B))
    print(f"{len(elements_A.intersection(elements_C))} Elements in A that match with C:")
    print(elements_A.intersection(elements_C))
    print(f"{len(elements_B.intersection(elements_C))} Elements in B that match with C:")
    print(elements_B.intersection(elements_C))

    print("\nElements that don't match:")
    print(f"{len(elements_A.difference(elements_B))} Elements in A that don't match with B:")
    print(elements_A.difference(elements_B))
    print(f"{len(elements_A.difference(elements_C))} Elements in A that don't match with C:")
    print(elements_A.difference(elements_C))
    print(f"{len(elements_B.difference(elements_C))} Elements in B that don't match with C:")
    print(elements_B.difference(elements_C))

    print(f"{len(elements_C.difference(elements_A))} Elements in C that don't match with A:")
    print(elements_C.difference(elements_A))
    print(f"{len(elements_C.difference(elements_B))} Elements in C that don't match with B:")
    print(elements_C.difference(elements_B))

# Find and print elements in A, B, and C and their intersections
find_elements(chemical_formulas)
# Out:
# Elements in A:
# {'Y', 'Zr', 'Pa', 'Ho', 'Cd', 'Li', 'Ce', 'Pd', 'Tl', 'Pb', 'Ga', 'Mn', 'Be', 'Ge', 'Th', 'In', 'Co', 'Au', 'P', 'Ba', 'Br', 'Tc', 'H', 'Eu', 'Hg', 'Sm', 'Mg', 'Pu', 'Te', 'W', 'Ca', 'Zn', 'Ni', 'Nb', 'K', 'Pt', 'Al', 'Gd', 'U', 'Sc', 'Bi', 'As', 'Cs', 'Os', 'Sn', 'Cu', 'Nd', 'Ta', 'Er', 'V', 'Cr', 'Re', 'Tb', 'Si', 'C', 'Tm', 'Fe', 'N', 'Sr', 'I', 'Na', 'Pr', 'Dy', 'Ti', 'Rb', 'Sb', 'Mo', 'La', 'Lu', 'Ag', 'Hf', 'S'}
# 72
# Elements in B:
# {'Pa', 'Zr', 'Y', 'Ho', 'Cd', 'Ce', 'Ru', 'Pd', 'Tl', 'Pb', 'Mn', 'Ga', 'Be', 'Ge', 'Th', 'In', 'Co', 'Au', 'P', 'Br', 'O', 'Tc', 'H', 'Eu', 'Hg', 'Sm', 'Pu', 'Te', 'W', 'Ca', 'Nb', 'Ni', 'Zn', 'Pt', 'Li', 'Al', 'Sc', 'Rh', 'U', 'Bi', 'As', 'Ta', 'Sn', 'Os', 'Cu', 'Hf', 'Tb', 'V', 'Cr', 'Er', 'Re', 'Si', 'Np', 'C', 'Tm', 'Fe', 'S', 'Cl', 'N', 'Sr', 'I', 'Na', 'Ir', 'Pr', 'Dy', 'Ti', 'Sb', 'Mo', 'Mg', 'Lu', 'Ag', 'Se', 'B'}
# 73
# Elements in C:
# {'Ru', 'Pd', 'Pb', 'Ge', 'In', 'F', 'Au', 'P', 'Br', 'H', 'Te', 'Ni', 'Pt', 'O', 'Al', 'Rh', 'As', 'Sn', 'Os', 'Cu', 'Si', 'C', 'Cl', 'N', 'I', 'Ir', 'Sb', 'B', 'Mo', 'Se', 'S'}
# 31
#
# Matching elements:
# 65 Elements in A that match with B:
# {'Y', 'Pa', 'Zr', 'Ho', 'Cd', 'Ce', 'Pd', 'Tl', 'Pb', 'Mn', 'Ga', 'Be', 'Ge', 'Th', 'In', 'Co', 'Au', 'P', 'Br', 'Tc', 'H', 'Eu', 'Hg', 'Sm', 'Pu', 'Te', 'W', 'Ca', 'Zn', 'Ni', 'Nb', 'Pt', 'Li', 'Al', 'Sc', 'U', 'Bi', 'As', 'Ta', 'Os', 'Sn', 'Cu', 'Er', 'V', 'Cr', 'Re', 'Tb', 'Si', 'C', 'Tm', 'Fe', 'N', 'Sr', 'I', 'Na', 'Pr', 'Dy', 'Ti', 'Sb', 'Mo', 'Mg', 'Lu', 'Ag', 'Hf', 'S'}
# 23 Elements in A that match with C:
# {'Pd', 'Pb', 'Ge', 'In', 'Au', 'P', 'Br', 'H', 'Te', 'Ni', 'Pt', 'Al', 'As', 'Sn', 'Os', 'Cu', 'Si', 'C', 'N', 'I', 'Sb', 'Mo', 'S'}
# 30 Elements in B that match with C:
# {'Ru', 'Pd', 'Pb', 'Ge', 'In', 'Au', 'P', 'Br', 'H', 'Te', 'Ni', 'Pt', 'O', 'Al', 'Rh', 'As', 'Sn', 'Os', 'Cu', 'Si', 'C', 'S', 'Cl', 'N', 'I', 'Ir', 'Sb', 'Mo', 'Se', 'B'}
#
# Elements that don't match:
# 7 Elements in A that don't match with B:
# {'K', 'Gd', 'Cs', 'Ba', 'Nd', 'Rb', 'La'}
# 49 Elements in A that don't match with C:
# {'Y', 'Pa', 'Zr', 'Ho', 'Cd', 'Ce', 'Tl', 'La', 'Mn', 'Ga', 'Be', 'Th', 'Co', 'Ba', 'Tc', 'Eu', 'Hg', 'Sm', 'Pu', 'W', 'Ca', 'Zn', 'Nb', 'K', 'Li', 'Sc', 'Gd', 'U', 'Bi', 'Cs', 'Ta', 'Nd', 'Er', 'V', 'Cr', 'Re', 'Tb', 'Tm', 'Fe', 'Sr', 'Na', 'Pr', 'Dy', 'Ti', 'Rb', 'Mg', 'Lu', 'Ag', 'Hf'}
# 43 Elements in B that don't match with C:
# {'Y', 'Pa', 'Zr', 'Ho', 'Cd', 'Ce', 'Tl', 'Mn', 'Ga', 'Be', 'Th', 'Co', 'Tc', 'Eu', 'Hg', 'Sm', 'Pu', 'W', 'Ca', 'Nb', 'Zn', 'Li', 'Sc', 'U', 'Bi', 'Ta', 'Tb', 'V', 'Cr', 'Er', 'Re', 'Np', 'Tm', 'Fe', 'Sr', 'Na', 'Pr', 'Dy', 'Ti', 'Mg', 'Lu', 'Ag', 'Hf'}
# 8 Elements in C that don't match with A:
# {'O', 'Cl', 'F', 'Rh', 'Ir', 'Ru', 'Se', 'B'}
# 1 Elements in C that don't match with B:
# {'F'}

# %%
chemical_formulas
# Out:
# array(['Ag3SBr', 'Ag3SI', 'AgAsO3', ..., 'NdNiGe3', 'NdNiO3', 'NdNiSb3'],
#       dtype=object)

# %%
import re
def remove_numbers(input_string):
    return re.sub(r'\d+', '', input_string)

a = (input("Input 1st element:")).capitalize()
b = (input("Input 2nd element:")).capitalize()
c = (input("Input 3rd element:")).capitalize()
input_combination = a+b+c

def check_element_exist(input_combination):
    for formula in perovs_feat['formula']:
        if remove_numbers(formula) == input_combination:
            return formula
    return False
status = check_element_exist(input_combination)
if status == False:
    print("Combination not found.")
elif status != False:
    print(status)
# Out:
# Input 1st element: ag
# Input 2nd element: s
# Input 3rd element: br
# Ag3SBr
